# %%
import requests

# Google Books API URL
BASE_URL = "https://www.googleapis.com/books/v1/volumes"

# Function to fetch books with pagination and filter industryIdentifiers
def fetch_books(query, max_results=1000, results_per_page=40, api_key = None):
    all_books = []
    start_index = 0  # Initial index to start fetching
    
    while start_index < max_results:
        # Send GET request with the query and pagination parameters
        response = requests.get(BASE_URL, params={
            'q': query,
            'startIndex': start_index,
            'maxResults': results_per_page
        })
        
        # If the response is successful
        if response.status_code == 200:
            data = response.json()
            books = data.get('items', [])
            
            # Filter industryIdentifiers to include only "ISBN_13" and "ISBN_10"
            for book in books:
                volume_info = book.get('volumeInfo', {})
                
                # Safely get 'industryIdentifiers', default to empty list if not found
                industry_identifiers = volume_info.get('industryIdentifiers', [])
                
                # Filter the industryIdentifiers by type (ISBN_13 and ISBN_10)
                filtered_identifiers = [identifier for identifier in industry_identifiers if identifier.get('type') in ['ISBN_13', 'ISBN_10']]
                
                # If there are any valid identifiers, concatenate them into a single string
                if filtered_identifiers:
                    concatenated_identifiers = ' | '.join([f"{identifier['type']}: {identifier['identifier']}" for identifier in filtered_identifiers])
                    volume_info['industryIdentifiers'] = concatenated_identifiers  # Store as a single string
                    all_books.append(book)
            
            # If we fetched less than requested, we are done
            if len(books) < results_per_page:
                break
            
            # Increment startIndex to fetch the next page of results
            start_index += results_per_page
        else:
            print(f"Error fetching data: {response.status_code}")
            break
    
    return all_books

# Example usage
query = "python programming"  # Search query (e.g., books related to Python programming)
api_key = "AIzaSyBa_59ZupTnQEOzwpiXh2w9sQuayhveCcY" 
books = fetch_books(query, max_results=1000, results_per_page=40, api_key=api_key)

# Print out the titles and concatenated industryIdentifiers of the fetched books
for idx, book in enumerate(books, start=1):
    title = book['volumeInfo'].get('title', 'No Title')
    concatenated_identifiers = book['volumeInfo'].get('industryIdentifiers', 'No Identifiers')
    
    # Display the book title and the concatenated industryIdentifiers
    print(f"{idx}. {title}")
    print(f"   - Identifiers: {concatenated_identifiers}")
# Out:
# 1. Learning Python
#    - Identifiers: ISBN_13: 9781449355715 | ISBN_10: 1449355714
# 2. Python Tutorial 3.11.3
#    - Identifiers: ISBN_10: 1312571659 | ISBN_13: 9781312571655
# 3. Introduction to Python Programming
#    - Identifiers: ISBN_13: 9781351013215 | ISBN_10: 1351013211
# 4. Python Programming
#    - Identifiers: ISBN_13: 9781887902991 | ISBN_10: 1887902996
# 5. Ultimate Python Programming
#    - Identifiers: ISBN_13: 9789355516558 | ISBN_10: 935551655X
# 6. Taming PYTHON By Programming
#    - Identifiers: ISBN_13: 9789386173348 | ISBN_10: 9386173344
# 7. Introduction to Computation and Programming Using Python, revised and expanded edition
#    - Identifiers: ISBN_13: 9780262316668 | ISBN_10: 0262316668
# 8. Python for Kids
#    - Identifiers: ISBN_13: 9781593274948 | ISBN_10: 1593274947
# 9. Modern Python Programming using ChatGPT
#    - Identifiers: ISBN_13: 9789365894318 | ISBN_10: 936589431X
# 10. LEARN PYTHON WITH 200 PROGRAMS
#    - Identifiers: ISBN_13: 9781649510747 | ISBN_10: 1649510748
# 11. Python Crash Course
#    - Identifiers: ISBN_13: 9781593277390 | ISBN_10: 1593277393
# 12. Python Programming
#    - Identifiers: ISBN_10: 0199480176 | ISBN_13: 9780199480173
# 13. Core Python Programming
#    - Identifiers: ISBN_13: 9780130260369 | ISBN_10: 0130260363
# 14. Introduction to Python Programming
#    - Identifiers: ISBN_13: 9781351013222 | ISBN_10: 135101322X
# 15. Programming and Problem Solving using Python
#    - Identifiers: ISBN_13: 9789333223829 | ISBN_10: 9333223827
# 16. Introduction to Programming in Python
#    - Identifiers: ISBN_13: 9780134076522 | ISBN_10: 0134076524
# 17. Classic Computer Science Problems in Swift
#    - Identifiers: ISBN_13: 9781638356110 | ISBN_10: 1638356114
# 18. Python
#    - Identifiers: ISBN_10: 1539530264 | ISBN_13: 9781539530268
# 19. Basics of Python Programming
#    - Identifiers: ISBN_13: 9789388511803 | ISBN_10: 9388511808
# 20. Programming with Python
#    - Identifiers: ISBN_13: 9789811032776 | ISBN_10: 9811032777
# 21. Bite-Size Python
#    - Identifiers: ISBN_13: 9781119643838 | ISBN_10: 111964383X
# 22. PYTHON PROGRAMMING
#    - Identifiers: ISBN_13: 9788119364084 | ISBN_10: 8119364082
# 23. The Big Book of Small Python Projects
#    - Identifiers: ISBN_13: 9781718501249 | ISBN_10: 1718501242
# 24. An Introduction to Python Programming: A Practical Approach
#    - Identifiers: ISBN_13: 9789391392062 | ISBN_10: 9391392067
# 25. An Introduction to Python and Computer Programming
#    - Identifiers: ISBN_13: 9789812876096 | ISBN_10: 981287609X
# 26. Python Programming
#    - Identifiers: ISBN_10: 1914185080 | ISBN_13: 9781914185083
# 27. Core Python Programming
#    - Identifiers: ISBN_10: 8131711889 | ISBN_13: 9788131711880
# 28. Python Programming For Beginners
#    - Identifiers: ISBN_13: 9781633830400 | ISBN_10: 1633830403
# 29. Python Programming in Context
#    - Identifiers: ISBN_13: 9781284175554 | ISBN_10: 1284175553
# 30. Python
#    - Identifiers: ISBN_10: 1653304278 | ISBN_13: 9781653304271
# 31. Python Programming
#    - Identifiers: ISBN_13: 9788119980581 | ISBN_10: 8119980581
# 32. Expert Python Programming
#    - Identifiers: ISBN_13: 9781801076197 | ISBN_10: 1801076197
# 33. An Introduction to Python Programming for Scientists and Engineers
#    - Identifiers: ISBN_13: 9781108701129 | ISBN_10: 1108701124
# 34. Python Programming Fundamentals
#    - Identifiers: ISBN_13: 9781447166429 | ISBN_10: 1447166426
# 35. Beginning Programming with Python For Dummies
#    - Identifiers: ISBN_13: 9781119457893 | ISBN_10: 1119457890
# 36. Invent Your Own Computer Games with Python, 4th Edition
#    - Identifiers: ISBN_13: 9781593277956 | ISBN_10: 1593277954
# 37. Programming for Computations - Python
#    - Identifiers: ISBN_13: 9783319324289 | ISBN_10: 3319324284
# 38. Introduction to Scientific Programming with Python
#    - Identifiers: ISBN_13: 9783030503567 | ISBN_10: 3030503569
# 39. Python Programming Blueprints
#    - Identifiers: ISBN_13: 9781786464903 | ISBN_10: 178646490X
# 40. Programming in Python 3
#    - Identifiers: ISBN_13: 9780321606594 | ISBN_10: 0321606590
# 41. Python 101
#    - Identifiers: ISBN_13: 9780996062817 | ISBN_10: 0996062815
# 42. PYTHON PROGRAMMING
#    - Identifiers: ISBN_10: 180154767X | ISBN_13: 9781801547673
# 43. Introduction to Digital Music with Python Programming
#    - Identifiers: ISBN_13: 9781000533415 | ISBN_10: 1000533417
# 44. Learning Python
#    - Identifiers: ISBN_13: 9780596554491 | ISBN_10: 0596554494
# 45. Python Programming and Numerical Methods
#    - Identifiers: ISBN_13: 9780128195505 | ISBN_10: 0128195509
# 46. Python for Everybody
#    - Identifiers: ISBN_10: 1530051126 | ISBN_13: 9781530051120
# 47. Murach's Python Programming (2nd Edition)
#    - Identifiers: ISBN_10: 1943872740 | ISBN_13: 9781943872749
# 48. Programming in Python
#    - Identifiers: ISBN_13: 9789386551276 | ISBN_10: 9386551276
# 49. Learn Python 3 the Hard Way
#    - Identifiers: ISBN_13: 9780134693903 | ISBN_10: 0134693906
# 50. Practical Programming
#    - Identifiers: ISBN_13: 9781680504125 | ISBN_10: 1680504126
# 51. Elements of Programming Interviews
#    - Identifiers: ISBN_13: 9781479274833 | ISBN_10: 1479274836
# 52. Let Us Python
#    - Identifiers: ISBN_13: 9789389423372 | ISBN_10: 9389423376
# 53. Python Programming for the Absolute Beginner
#    - Identifiers: ISBN_10: 1592000738 | ISBN_13: 9781592000739
# 54. Python Cookbook
#    - Identifiers: ISBN_13: 9781449357351 | ISBN_10: 1449357350
# 55. Get Programming
#    - Identifiers: ISBN_13: 9781638355922 | ISBN_10: 1638355924
# 56. Powerful Python
#    - Identifiers: ISBN_13: 9781098175672 | ISBN_10: 1098175670
# 57. Advanced Python Programming
#    - Identifiers: ISBN_13: 9781838553692 | ISBN_10: 183855369X
# 58. Programming for Computations - Python
#    - Identifiers: ISBN_13: 9783030168773 | ISBN_10: 3030168778
# 59. Pythonic Programming
#    - Identifiers: ISBN_13: 9781680509205 | ISBN_10: 1680509209
# 60. Python Made Simple
#    - Identifiers: ISBN_13: 9789388511025 | ISBN_10: 9388511026
# 61. Learn Web Development with Python
#    - Identifiers: ISBN_13: 9781789950885 | ISBN_10: 1789950880
# 62. Python Programming in Context
#    - Identifiers: ISBN_13: 9781449691974 | ISBN_10: 1449691978
# 63. Coding for Kids: Python
#    - Identifiers: ISBN_10: 1641521759 | ISBN_13: 9781641521758
# 64. Python for Teenagers
#    - Identifiers: ISBN_13: 9781484245507 | ISBN_10: 1484245504
# 65. Programming in Python 3
#    - Identifiers: ISBN_13: 9780321699879 | ISBN_10: 0321699874
# 66. Python Programming for Data Analysis
#    - Identifiers: ISBN_13: 9783030689520 | ISBN_10: 3030689522
# 67. A Primer on Scientific Programming with Python
#    - Identifiers: ISBN_13: 9783662498873 | ISBN_10: 3662498871
# 68. Fluent Python
#    - Identifiers: ISBN_13: 9781491946251 | ISBN_10: 1491946253
# 69. Competitive Programming in Python
#    - Identifiers: ISBN_13: 9781108716826 | ISBN_10: 1108716822
# 70. A Beginners Guide to Python 3 Programming
#    - Identifiers: ISBN_13: 9783031351228 | ISBN_10: 3031351223
# 71. Python Basics
#    - Identifiers: ISBN_10: 1775093328 | ISBN_13: 9781775093329
# 72. Python Programming for Biology
#    - Identifiers: ISBN_13: 9780521895835 | ISBN_10: 0521895839
# 73. Conceptual Programming with Python
#    - Identifiers: ISBN_13: 9780244822767 | ISBN_10: 024482276X
# 74. Python Programming on Win32
#    - Identifiers: ISBN_13: 9781565926219 | ISBN_10: 1565926218
# 75. Python Crash Course, 2nd Edition
#    - Identifiers: ISBN_13: 9781593279288 | ISBN_10: 1593279280
# 76. Advanced Python Programming
#    - Identifiers: ISBN_13: 9781801817776 | ISBN_10: 1801817774
# 77. Expert Python Programming
#    - Identifiers: ISBN_13: 9781789806779 | ISBN_10: 1789806771
# 78. Learn Python Programming
#    - Identifiers: ISBN_10: 1080867708 | ISBN_13: 9781080867707
# 79. Coding for Beginners: Using Python
#    - Identifiers: ISBN_13: 9781474935753 | ISBN_10: 1474935753
# 80. Artificial Intelligence with Python
#    - Identifiers: ISBN_13: 9781786469670 | ISBN_10: 1786469677
# 81. Non-Programmers Tutorial For Python 2 and 3
#    - Identifiers: ISBN_13: 9781387757190 | ISBN_10: 1387757199
# 82. PYTHON PROGRAMMING FOR NEWBIES
#    - Identifiers: ISBN_13: 9789354458385 | ISBN_10: 9354458386
# 83. Learn Python Programming - Third Edition
#    - Identifiers: ISBN_10: 1801815097 | ISBN_13: 9781801815093
# 84. Python
#    - Identifiers: ISBN_10: 1683926242 | ISBN_13: 9781683926245
# 85. Python Tricks
#    - Identifiers: ISBN_10: 1775093301 | ISBN_13: 9781775093305
# 86. Think Python
#    - Identifiers: ISBN_13: 9781491939413 | ISBN_10: 1491939419
# 87. Python Data Science Handbook
#    - Identifiers: ISBN_13: 9781491912133 | ISBN_10: 1491912138
# 88. Violent Python
#    - Identifiers: ISBN_13: 9781597499644 | ISBN_10: 1597499641
# 89. An Introduction to Statistical Learning
#    - Identifiers: ISBN_13: 9783031387470 | ISBN_10: 3031387473
# 90. Python Programming with Applications: from Basics to Advance
#    - Identifiers: ISBN_13: 9788196401870 | ISBN_10: 8196401876
# 91. Python Programming for Beginners - Learn the Basics of Python in 7 Days!
#    - Identifiers: ISBN_10: 1980501114 | ISBN_13: 9781980501114
# 92. Foundations of Python Network Programming
#    - Identifiers: ISBN_13: 9781430230045 | ISBN_10: 1430230045
# 93. Python Programming for Arduino
#    - Identifiers: ISBN_13: 9781783285945 | ISBN_10: 178328594X
# 94. Python Programming
#    - Identifiers: ISBN_10: 1539434370 | ISBN_13: 9781539434375
# 95. Deep Learning for Coders with fastai and PyTorch
#    - Identifiers: ISBN_13: 9781492045496 | ISBN_10: 1492045497
# 96. Gray Hat Python
#    - Identifiers: ISBN_13: 9781593271923 | ISBN_10: 1593271921
# 97. Head First Learn to Code
#    - Identifiers: ISBN_13: 9781491958810 | ISBN_10: 1491958812
# 98. Game Programming Patterns
#    - Identifiers: ISBN_13: 9780990582915 | ISBN_10: 0990582914
# 99. Advance Core Python Programming
#    - Identifiers: ISBN_13: 9789390684069 | ISBN_10: 9390684064
# 100. Python Programming for Advanced
#    - Identifiers: ISBN_10: 152143963X | ISBN_13: 9781521439630
# 101. High Performance Python
#    - Identifiers: ISBN_13: 9781492054993 | ISBN_10: 1492054992
# 102. Internet Programming with Python
#    - Identifiers: ISBN_10: 1558514848 | ISBN_13: 9781558514843
# 103. Teach Your Kids to Code
#    - Identifiers: ISBN_13: 9781593276812 | ISBN_10: 1593276818
# 104. Basic Core Python Programming
#    - Identifiers: ISBN_13: 9789390684953 | ISBN_10: 9390684951
# 105. Python Programming
#    - Identifiers: ISBN_13: 9798643669333
# 106. A Concise Introduction to Programming in Python
#    - Identifiers: ISBN_13: 9781351621991 | ISBN_10: 1351621998
# 107. Learn to Program with Python 3
#    - Identifiers: ISBN_13: 9781484238790 | ISBN_10: 1484238796
# 108. Natural Language Processing with Python
#    - Identifiers: ISBN_13: 9780596555719 | ISBN_10: 0596555717
# 109. Python Programming
#    - Identifiers: ISBN_10: 1670614239 | ISBN_13: 9781670614230
# 110. How To Code in Python 3
#    - Identifiers: ISBN_13: 9780999773000 | ISBN_10: 0999773003
# 111. Python Programming for Raspberry Pi, Sams Teach Yourself in 24 Hourss
#    - Identifiers: ISBN_13: 9780133490176 | ISBN_10: 0133490173
# 112. Python Programming in Context
#    - Identifiers: ISBN_13: 9781284018592 | ISBN_10: 1284018598
# 113. Python Programming for Intermediates
#    - Identifiers: ISBN_10: 1980814856 | ISBN_13: 9781980814856
# 114. Python Network Programming
#    - Identifiers: ISBN_13: 9781788830232 | ISBN_10: 1788830237
# 115. Python for Beginners
#    - Identifiers: ISBN_13: 9788827589502 | ISBN_10: 8827589503
# 116. Get Started with MicroPython on Raspberry Pi Pico
#    - Identifiers: ISBN_13: 9781912047161 | ISBN_10: 1912047160
# 117. Learning Scientific Programming with Python
#    - Identifiers: ISBN_13: 9781108787468 | ISBN_10: 1108787460
# 118. Python
#    - Identifiers: ISBN_13: 9780132104128 | ISBN_10: 0132104121
# 119. Python In - Depth
#    - Identifiers: ISBN_13: 9789389328424 | ISBN_10: 938932842X
# 120. PROBLEM SOLVING AND PYTHON PROGRAMMING
#    - Identifiers: ISBN_13: 9780359456086 | ISBN_10: 0359456081
# 121. O' Level Made Simple - Programming And Problems Solving Through C Language (M4.1-R3 & A3-R3)-2Nd Rev. Edn
#    - Identifiers: ISBN_10: 8176567302 | ISBN_13: 9788176567305
# 122. Learn Python Programming for Beginners
#    - Identifiers: ISBN_13: 9798669102517
# 123. Python Crash Course
#    - Identifiers: ISBN_10: 1077579640 | ISBN_13: 9781077579644
# 124. Learn Python Programming
#    - Identifiers: ISBN_10: 1801239088 | ISBN_13: 9781801239080
# 125. Python Programming for Beginners
#    - Identifiers: ISBN_10: 1511787457 | ISBN_13: 9781511787451
# 126. Python Programming For Beginners
#    - Identifiers: ISBN_10: 1075311934 | ISBN_13: 9781075311932
# 127. Python Programming
#    - Identifiers: ISBN_13: 9781000434415 | ISBN_10: 1000434419
# 128. Python Programming
#    - Identifiers: ISBN_10: 1795234318 | ISBN_13: 9781795234313
# 129. Ruby for Beginners
#    - Identifiers: ISBN_10: 1521367701 | ISBN_13: 9781521367704
# 130. Programming with Python for Social Scientists
#    - Identifiers: ISBN_13: 9781526486349 | ISBN_10: 1526486342
# 131. Python Programming in a Day and JavaScript Professional Programming Made Easy
#    - Identifiers: ISBN_10: 1511442476 | ISBN_13: 9781511442473
# 132. Introduction to Python Programming for Business and Social Science Applications
#    - Identifiers: ISBN_13: 9781544377483 | ISBN_10: 1544377487
# 133. A Hands-On Introduction to Data Science
#    - Identifiers: ISBN_13: 9781108472449 | ISBN_10: 1108472443
# 134. Python Programming
#    - Identifiers: ISBN_13: 9798673703328
# 135. Python programming for Data Scientists
#    - Identifiers: ISBN_13: 9781708620288 | ISBN_10: 1708620281
# 136. HT THINK LIKE A COMPUTER SCIEN
#    - Identifiers: ISBN_10: 9888406787 | ISBN_13: 9789888406784
# 137. Basics of Python Programming: A Quick Guide for Beginners
#    - Identifiers: ISBN_13: 9789815179644 | ISBN_10: 9815179640
# 138. Python for Professionals
#    - Identifiers: ISBN_13: 9789389423730 | ISBN_10: 9389423732
# 139. Python Programming
#    - Identifiers: ISBN_13: 9798671744071
# 140. Python For Beginners
#    - Identifiers: ISBN_10: 191336190X | ISBN_13: 9781913361907
# 141. Introducing Python
#    - Identifiers: ISBN_13: 9781492051329 | ISBN_10: 1492051322
# 142. Tkinter GUI Application Development Cookbook
#    - Identifiers: ISBN_13: 9781788627771 | ISBN_10: 1788627776
# 143. Learn Python the Hard Way
#    - Identifiers: ISBN_13: 9780321884916 | ISBN_10: 0321884914
# 144. Python Programming
#    - Identifiers: ISBN_10: 1701469618 | ISBN_13: 9781701469617
# 145. Learning Python
#    - Identifiers: ISBN_13: 9781449355692 | ISBN_10: 1449355692
# 146. Python Programming Crash Course
#    - Identifiers: ISBN_10: 1801116024 | ISBN_13: 9781801116022
# 147. Python in Education
#    - Identifiers: ISBN_10: 1491924624 | ISBN_13: 9781491924624
# 148. Let Us Python
#    - Identifiers: ISBN_13: 9789389845037 | ISBN_10: 9389845033
# 149. Learning Python by Building Games
#    - Identifiers: ISBN_10: 1789802989 | ISBN_13: 9781789802986
# 150. Learn to Code by Solving Problems
#    - Identifiers: ISBN_13: 9781718501324 | ISBN_10: 1718501323
# 151. Python Programming for Beginners
#    - Identifiers: ISBN_10: 1501000861 | ISBN_13: 9781501000867
# 152. Practical Python Programming for IoT
#    - Identifiers: ISBN_13: 9781838982836 | ISBN_10: 1838982833
# 153. Python Programming
#    - Identifiers: ISBN_10: 1532737076 | ISBN_13: 9781532737077
# 154. Python Programming
#    - Identifiers: ISBN_10: 1801825882 | ISBN_13: 9781801825887
# 155. Python Programming Professional Made Easy and C Programming Success in a Day
#    - Identifiers: ISBN_10: 150896436X | ISBN_13: 9781508964360
# 156. Python Programming in a Day and C Programming Success in a Day and C Programming Professional Made Easy
#    - Identifiers: ISBN_10: 1511412305 | ISBN_13: 9781511412308
# 157. Beyond the Basic Stuff with Python
#    - Identifiers: ISBN_13: 9781593279660 | ISBN_10: 1593279663
# 158. Python Programming
#    - Identifiers: ISBN_10: 191398785X | ISBN_13: 9781913987855
# 159. Python Programming: The Ultimate Beginner's Guide to Python Language Fundamentals, a Crash Course with Step-by-Step Exercises, Tips, and T
#    - Identifiers: ISBN_10: 1913922413 | ISBN_13: 9781913922412
# 160. Practical Python Programming Practices (101 Common Projects)
#    - Identifiers: ISBN_13: 9798737194819
# 161. The Hitchhiker's Guide to Python
#    - Identifiers: ISBN_13: 9781491933220 | ISBN_10: 1491933224
# 162. Python Programming
#    - Identifiers: ISBN_10: 1543093043 | ISBN_13: 9781543093049
# 163. Programming Microcontrollers with Python
#    - Identifiers: ISBN_10: 1484270576 | ISBN_13: 9781484270578
# 164. Python Essential Reference
#    - Identifiers: ISBN_13: 9780768687026 | ISBN_10: 0768687020
# 165. Python Programming with the Java Class Libraries
#    - Identifiers: ISBN_13: 9780201616163 | ISBN_10: 0201616165
# 166. Practices of the Python Pro
#    - Identifiers: ISBN_13: 9781638350132 | ISBN_10: 1638350132
# 167. Python and Tkinter Programming
#    - Identifiers: ISBN_10: 1884777813 | ISBN_13: 9781884777813
# 168. Python Programming
#    - Identifiers: ISBN_10: 1687652686 | ISBN_13: 9781687652683
# 169. The New And Improved Flask Mega-Tutorial
#    - Identifiers: ISBN_13: 9798811478408
# 170. Python for Programmers
#    - Identifiers: ISBN_13: 9780135231340 | ISBN_10: 0135231345
# 171. Programming Computer Vision with Python
#    - Identifiers: ISBN_13: 9781449341930 | ISBN_10: 1449341934
# 172. Python Programming
#    - Identifiers: ISBN_10: 1801545928 | ISBN_13: 9781801545921
# 173. Functional Programming in Python
#    - Identifiers: ISBN_10: 1985826747 | ISBN_13: 9781985826748
# 174. Python Programming and Machine Learning
#    - Identifiers: ISBN_13: 9798638670719
# 175. Head First Python
#    - Identifiers: ISBN_13: 9781491919491 | ISBN_10: 1491919493
# 176. Learn Python in 1 Day
#    - Identifiers: ISBN_10: 1729235581 | ISBN_13: 9781729235584
# 177. Python Programming
#    - Identifiers: ISBN_13: 9789367868423 | ISBN_10: 9367868421
# 178. Python Programming for Intermediates
#    - Identifiers: ISBN_10: 1521439559 | ISBN_13: 9781521439555
# 179. PYTHON PROGRAMMING
#    - Identifiers: ISBN_13: 9788196176938 | ISBN_10: 8196176937
# 180. A Journey to Core Python
#    - Identifiers: ISBN_13: 9789355511249 | ISBN_10: 9355511248
# 181. Coding
#    - Identifiers: ISBN_10: 1801690219 | ISBN_13: 9781801690218
# 182. Python Programming
#    - Identifiers: ISBN_10: 1693307588 | ISBN_13: 9781693307584
# 183. Python Programming
#    - Identifiers: ISBN_10: 1801135673 | ISBN_13: 9781801135672
# 184. Effective Python
#    - Identifiers: ISBN_13: 9780134034409 | ISBN_10: 0134034406
# 185. Problem Solving and Python Programming
#    - Identifiers: ISBN_13: 9789352834853 | ISBN_10: 9352834852
# 186. PYTHON PROGRAMMING
#    - Identifiers: ISBN_13: 9789386739261 | ISBN_10: 9386739267
# 187. Python Programming Professional Made Easy and C Programming Professional Made Easy
#    - Identifiers: ISBN_10: 1508964289 | ISBN_13: 9781508964285
# 188. Python Programming for Beginners: Learn the Fundamentals of Python in 7 Days
#    - Identifiers: ISBN_10: 1521432341 | ISBN_13: 9781521432341
# 189. Python Programming
#    - Identifiers: ISBN_10: 1647710685 | ISBN_13: 9781647710682
# 190. Mathematics and Python Programming
#    - Identifiers: ISBN_13: 9781326017965 | ISBN_10: 1326017969
# 191. The Best Python Programming Step-By-Step Beginners Guide
#    - Identifiers: ISBN_10: 195234011X | ISBN_13: 9781952340116
# 192. Python Programming Professional Made Easy and PHP Programming Professional Made Easy
#    - Identifiers: ISBN_10: 1514179636 | ISBN_13: 9781514179635
# 193. Python Programming
#    - Identifiers: ISBN_10: 1986278573 | ISBN_13: 9781986278577
# 194. Rapid GUI Programming with Python and Qt
#    - Identifiers: ISBN_13: 9780132703062 | ISBN_10: 0132703068
# 195. Python Programming
#    - Identifiers: ISBN_10: 1951783808 | ISBN_13: 9781951783808
# 196. Data Visualization using Python Programming-
#    - Identifiers: ISBN_13: 9788119084722 | ISBN_10: 8119084721
# 197. Python 3 Object Oriented Programming
#    - Identifiers: ISBN_13: 9781849511278 | ISBN_10: 1849511276
# 198. Advanced Python Programming
#    - Identifiers: ISBN_10: 1979604967 | ISBN_13: 9781979604963
# 199. Python Programming
#    - Identifiers: ISBN_10: 153279570X | ISBN_13: 9781532795701
# 200. Python Programming
#    - Identifiers: ISBN_10: 1801121702 | ISBN_13: 9781801121705
# 201. Python Programming in a Day and MYSQL Programming Professional Made Easy
#    - Identifiers: ISBN_10: 1511442409 | ISBN_13: 9781511442404
# 202. Coding Projects in Python
#    - Identifiers: ISBN_10: 0606401245 | ISBN_13: 9780606401241
# 203. Pragmatic Python Programming
#    - Identifiers: ISBN_10: 1484281519 | ISBN_13: 9781484281512
# 204. Python Programming
#    - Identifiers: ISBN_10: 1698127227 | ISBN_13: 9781698127224
# 205. Python Programming
#    - Identifiers: ISBN_10: 1692052667 | ISBN_13: 9781692052669
# 206. Python: Journey from Novice to Expert
#    - Identifiers: ISBN_13: 9781787122567 | ISBN_10: 1787122565
# 207. Python for Software Design
#    - Identifiers: ISBN_13: 9781139479226 | ISBN_10: 1139479229
# 208. Python Programming
#    - Identifiers: ISBN_13: 9781040100431 | ISBN_10: 1040100430
# 209. Python Programming Crash Course
#    - Identifiers: ISBN_13: 9798644764310
# 210. Dive Into Python
#    - Identifiers: ISBN_13: 9781430207009 | ISBN_10: 1430207000
# 211. Python Programming
#    - Identifiers: ISBN_10: 169177099X | ISBN_13: 9781691770991
# 212. Python Programming Professional Made Easy and CSS Programming Professional Made Easy
#    - Identifiers: ISBN_10: 1514179741 | ISBN_13: 9781514179741
# 213. Python Programming in a Day and C Programming Professional Made Easy
#    - Identifiers: ISBN_10: 1508964203 | ISBN_13: 9781508964209
# 214. Hello Raspberry Pi!
#    - Identifiers: ISBN_13: 9781638352440 | ISBN_10: 1638352445
# 215. Black Hat Python, 2nd Edition
#    - Identifiers: ISBN_13: 9781718501133 | ISBN_10: 1718501137
# 216. Python
#    - Identifiers: ISBN_10: 007212718X | ISBN_13: 9780072127188
# 217. Learn Python Programming
#    - Identifiers: ISBN_13: 9781801815529 | ISBN_10: 1801815526
# 218. Hands-on Python
#    - Identifiers: ISBN_10: 1724355937 | ISBN_13: 9781724355935
# 219. Core Python Applications Programming
#    - Identifiers: ISBN_13: 9780132678209 | ISBN_10: 0132678209
# 220. Hands on Programming with Python
#    - Identifiers: ISBN_13: 9798656766715
# 221. The Python Book
#    - Identifiers: ISBN_10: 1783896477 | ISBN_13: 9781783896479
# 222. Python Challenges
#    - Identifiers: ISBN_10: 1484273974 | ISBN_13: 9781484273975
# 223. Python Programming Books Set
#    - Identifiers: ISBN_10: 1514618907 | ISBN_13: 9781514618905
# 224. Python Programming Books Set
#    - Identifiers: ISBN_10: 1514618907 | ISBN_13: 9781514618905
# 225. Python Programming for Students
#    - Identifiers: ISBN_10: 9355517262 | ISBN_13: 9789355517265
# 226. Coding for Kids in Python
#    - Identifiers: ISBN_10: 1922462977 | ISBN_13: 9781922462978
# 227. The Quick Python Book
#    - Identifiers: ISBN_10: 193518220X | ISBN_13: 9781935182207
# 228. Python Programming Techniques
#    - Identifiers: ISBN_13: 9781632873330 | ISBN_10: 1632873338
# 229. How to Code in Python 3
#    - Identifiers: ISBN_10: 0999773011 | ISBN_13: 9780999773017
# 230. Python Programming Exam Essentials
#    - Identifiers: ISBN_13: 9781836794875 | ISBN_10: 1836794878
# 231. Python Programming for Machine Learning
#    - Identifiers: ISBN_13: 9789363485235 | ISBN_10: 9363485234
# 232. Python Programming for Linguistics and Digital Humanities
#    - Identifiers: ISBN_13: 9781119907947 | ISBN_10: 1119907942
# 233. Python Programming – A Modern Approach
#    - Identifiers: ISBN_13: 9788197427237 | ISBN_10: 8197427232
# 234. Python Programming for Raspberry Pi, Sams Teach Yourself in 24 Hours
#    - Identifiers: ISBN_13: 9780134389578 | ISBN_10: 0134389573
# 235. Core Python Programming
#    - Identifiers: ISBN_10: 8131735427 | ISBN_13: 9788131735428
# 236. Problem Solving using Python Programming
#    - Identifiers: ISBN_13: 9789364927628 | ISBN_10: 9364927621
# 237. PYTHON PROGRAMMING FOR GIS
#    - Identifiers: ISBN_13: 9789360925444 | ISBN_10: 9360925446
# 238. Python Programming Recipes for IoT Applications
#    - Identifiers: ISBN_13: 9789811994661 | ISBN_10: 9811994668
# 239. Problem Solving & Python Programming
#    - Identifiers: ISBN_13: 9788197665752 | ISBN_10: 8197665753
# 240. Python Programming Guide for GCSE Computer Science (includes Python Files)
#    - Identifiers: ISBN_13: 9781789088625 | ISBN_10: 1789088623
# 241. Expert Python Programming
#    - Identifiers: ISBN_13: 9781785884399 | ISBN_10: 1785884395
# 242. Python Machine Learning
#    - Identifiers: ISBN_13: 9781783555147 | ISBN_10: 1783555149
# 243. Supervised Machine Learning with Python
#    - Identifiers: ISBN_13: 9781838823061 | ISBN_10: 1838823069
# 244. Python Programming Intermediate
#    - Identifiers: ISBN_10: 1678465968 | ISBN_13: 9781678465964
# 245. Geospatial Application Development Using Python Programming
#    - Identifiers: ISBN_13: 9798369317556
# 246. Learn More Python 3 the Hard Way
#    - Identifiers: ISBN_13: 9780134123004 | ISBN_10: 013412300X
# 247. Python for Data Analysis
#    - Identifiers: ISBN_10: 1696532051 | ISBN_13: 9781696532051
# 248. Python Programming Professional Made Easy and MYSQL Programming Professional Made Easy
#    - Identifiers: ISBN_10: 1511966300 | ISBN_13: 9781511966306
# 249. Learning Python
#    - Identifiers: ISBN_13: 9781449379322 | ISBN_10: 144937932X
# 250. Python Programming : How to Code Python Fast In Just 24 Hours With 7 Simple Steps
#    - Identifiers: ISBN_13: 9781630222468 | ISBN_10: 1630222461
# 251. Python Essentials 2: Aligned with PCAP Certified Associate in Python Programming
#    - Identifiers: ISBN_13: 9798987762219
# 252. Python Parallel Programming Cookbook
#    - Identifiers: ISBN_13: 9781785286728 | ISBN_10: 1785286722
# 253. Python GUI Programming - A Complete Reference Guide
#    - Identifiers: ISBN_13: 9781838982102 | ISBN_10: 1838982108
# 254. Cracking Codes with Python
#    - Identifiers: ISBN_13: 9781593278229 | ISBN_10: 1593278225
# 255. Coding Interview Questions
#    - Identifiers: ISBN_10: 8192107515 | ISBN_13: 9788192107516
# 256. Complete Guide for Python Programming
#    - Identifiers: ISBN_10: 1511847743 | ISBN_13: 9781511847742
# 257. Python Programming
#    - Identifiers: ISBN_10: 1980931739 | ISBN_13: 9781980931737
# 258. PYTHON PROGRAMMING FOR COMPUTER SCIENCE
#    - Identifiers: ISBN_13: 9789390388288 | ISBN_10: 9390388287
# 259. Basic And Advance : Python Programming
#    - Identifiers: ISBN_13: 9789391383633 | ISBN_10: 9391383637
# 260. Python For Dummies
#    - Identifiers: ISBN_13: 9781118084847 | ISBN_10: 1118084845
# 261. Adventures in Python
#    - Identifiers: ISBN_13: 9781118951842 | ISBN_10: 1118951840
# 262. Teaching Python Programming - Practical Version
#    - Identifiers: ISBN_13: 9798874463342
# 263. Principles of Soft Computing Using Python Programming
#    - Identifiers: ISBN_13: 9781394173136 | ISBN_10: 139417313X
# 264. Python Coding
#    - Identifiers: ISBN_10: 1702712796 | ISBN_13: 9781702712798
# 265. Supercharged Python
#    - Identifiers: ISBN_13: 9780135160794 | ISBN_10: 0135160790
# 266. Python Made Easy
#    - Identifiers: ISBN_13: 9781649837264 | ISBN_10: 1649837267
# 267. Deep Learning with Python
#    - Identifiers: ISBN_13: 9781638352044 | ISBN_10: 1638352046
# 268. Python Pocket Reference
#    - Identifiers: ISBN_13: 9781449356941 | ISBN_10: 144935694X
# 269. PYTHON PROGRAMMING
#    - Identifiers: ISBN_10: 9918951273 | ISBN_13: 9789918951277
# 270. Python Programming
#    - Identifiers: ISBN_10: 1790110025 | ISBN_13: 9781790110025
# 271. Computer Science
#    - Identifiers: ISBN_13: 9780134076454 | ISBN_10: 0134076451
# 272. Expert Python Programming
#    - Identifiers: ISBN_10: 184719494X | ISBN_13: 9781847194947
# 273. Introduction to Python Programming
#    - Identifiers: ISBN_10: 1976773717 | ISBN_13: 9781976773716
# 274. Functional Python Programming
#    - Identifiers: ISBN_13: 9781784397616 | ISBN_10: 178439761X
# 275. Deep Learning from Scratch
#    - Identifiers: ISBN_13: 9781492041382 | ISBN_10: 1492041386
# 276. Hello World!
#    - Identifiers: ISBN_10: 161729702X | ISBN_13: 9781617297021
# 277. A Byte of Python
#    - Identifiers: ISBN_10: 1977878490 | ISBN_13: 9781977878496
# 278. The Self-taught Programmer
#    - Identifiers: ISBN_13: 9781472147097 | ISBN_10: 147214709X
# 279. Programming with Python for Social Scientists
#    - Identifiers: ISBN_13: 9781526486363 | ISBN_10: 1526486369
# 280. Learn Python in One Day and Learn It Well (2nd Edition)
#    - Identifiers: ISBN_10: 1546488332 | ISBN_13: 9781546488330
# 281. Python for Informatics
#    - Identifiers: ISBN_10: 1492339245 | ISBN_13: 9781492339243
# 282. Python Programming
#    - Identifiers: ISBN_13: 9798738963759
# 283. Programming with MicroPython
#    - Identifiers: ISBN_13: 9781491972717 | ISBN_10: 1491972718
# 284. Python Programming Guide. Exploring Computer Programming
#    - Identifiers: ISBN_13: 9783346227386 | ISBN_10: 3346227383
# 285. Python Programming Blueprints
#    - Identifiers: ISBN_10: 1786468166 | ISBN_13: 9781786468161
# 286. Python 3 Object-oriented Programming
#    - Identifiers: ISBN_13: 9781784395957 | ISBN_10: 1784395951
# 287. Python Interviews
#    - Identifiers: ISBN_13: 9781788391764 | ISBN_10: 1788391764
# 288. Functional Python Programming
#    - Identifiers: ISBN_13: 9781788621854 | ISBN_10: 1788621859
# 289. Structure and Interpretation of Computer Programs, second edition
#    - Identifiers: ISBN_13: 9780262510875 | ISBN_10: 0262510871
# 290. Pandas for Everyone
#    - Identifiers: ISBN_13: 9780134547053 | ISBN_10: 0134547055
# 291. Python Programming
#    - Identifiers: ISBN_10: 1096396599 | ISBN_13: 9781096396598
# 292. Effective Python
#    - Identifiers: ISBN_10: 7115634068 | ISBN_13: 9787115634061
# 293. Python Programming for Beginners
#    - Identifiers: ISBN_13: 9798696629568
# 294. Learning Python Networking
#    - Identifiers: ISBN_13: 9781789952445 | ISBN_10: 1789952441
# 295. Python Packages
#    - Identifiers: ISBN_10: 1003189253 | ISBN_13: 9781003189251
# 296. Python Machine Learning for Beginners
#    - Identifiers: ISBN_10: 1097858308 | ISBN_13: 9781097858309
# 297. Python Programming, Deep Learning
#    - Identifiers: ISBN_13: 9798636578581
# 298. Serious Python
#    - Identifiers: ISBN_13: 9781593278793 | ISBN_10: 1593278799
# 299. Python Programming
#    - Identifiers: ISBN_10: 1393439543 | ISBN_13: 9781393439547
# 300. Introduction to Digital Music with Python Programming
#    - Identifiers: ISBN_13: 9781000533385 | ISBN_10: 1000533387
# 301. The Python Bible 7 in 1
#    - Identifiers: ISBN_13: 9798629849124
# 302. Advanced Python Programming
#    - Identifiers: ISBN_10: 1838551212 | ISBN_13: 9781838551216
# 303. Python Essential Reference
#    - Identifiers: ISBN_13: 9780672329784 | ISBN_10: 0672329786
# 304. Mastering Django: Core
#    - Identifiers: ISBN_13: 9781787286344 | ISBN_10: 1787286347
# 305. Mastering C++
#    - Identifiers: ISBN_10: 0028010000 | ISBN_13: 9780028010007
# 306. Numerical Python
#    - Identifiers: ISBN_13: 9798868804137
# 307. Data Structure and Algorithmic Thinking with Python
#    - Identifiers: ISBN_10: 8192107590 | ISBN_13: 9788192107592
# 308. The Python Language Reference Manual
#    - Identifiers: ISBN_10: 1906966141 | ISBN_13: 9781906966140
# 309. More Python Programming for the Absolute Beginner
#    - Identifiers: ISBN_10: 1435459806 | ISBN_13: 9781435459809
# 310. Data Science and Machine Learning with Python
#    - Identifiers: ISBN_10: 8194633494 | ISBN_13: 9788194633495
# 311. Learning Python Application Development
#    - Identifiers: ISBN_10: 1785889192 | ISBN_13: 9781785889196
# 312. Programming Python
#    - Identifiers: ISBN_13: 9781449302757 | ISBN_10: 1449302750
# 313. Learning Python
#    - Identifiers: ISBN_10: 1600330215 | ISBN_13: 9781600330216
# 314. Raspberry Pi Supercomputing and Scientific Programming
#    - Identifiers: ISBN_13: 9781484228784 | ISBN_10: 1484228782
# 315. Programming Challenges
#    - Identifiers: ISBN_13: 9780387220819 | ISBN_10: 038722081X
# 316. Programming Languages
#    - Identifiers: ISBN_10: 1801571376 | ISBN_13: 9781801571371
# 317. Financial Modelling in Python
#    - Identifiers: ISBN_13: 9780470747896 | ISBN_10: 0470747897
# 318. 40 Algorithms Every Programmer Should Know
#    - Identifiers: ISBN_13: 9781789809862 | ISBN_10: 178980986X
# 319. Data Science for Marketing Analytics
#    - Identifiers: ISBN_13: 9781800563889 | ISBN_10: 1800563884
# 320. SPSS For Dummies
#    - Identifiers: ISBN_13: 9780470169506 | ISBN_10: 0470169508
# 321. Let Us Python Solutions
#    - Identifiers: ISBN_13: 9789389845013 | ISBN_10: 9389845017
# 322. Get Programming with Go
#    - Identifiers: ISBN_13: 9781638355472 | ISBN_10: 1638355479
# 323. Python in a Nutshell
#    - Identifiers: ISBN_13: 9780596100469 | ISBN_10: 0596100469
# 324. Sams Teach Yourself Python Programming for Raspberry Pi in 24 Hours
#    - Identifiers: ISBN_10: 0134389581 | ISBN_13: 9780134389585
# 325. Odoo 15 Development Essentials
#    - Identifiers: ISBN_13: 9781800203082 | ISBN_10: 180020308X
# 326. Python in Practice
#    - Identifiers: ISBN_13: 9780133373233 | ISBN_10: 0133373231
# 327. Learning OpenCV 4 Computer Vision with Python 3
#    - Identifiers: ISBN_13: 9781789530643 | ISBN_10: 1789530644
# 328. Python Network Programming Cookbook
#    - Identifiers: ISBN_10: 1849513465 | ISBN_13: 9781849513463
# 329. Image Processing and Acquisition using Python
#    - Identifiers: ISBN_13: 9781466583757 | ISBN_10: 1466583754
# 330. Clean Code in Python
#    - Identifiers: ISBN_13: 9781800562097 | ISBN_10: 1800562098
# 331. Python All-in-One For Dummies
#    - Identifiers: ISBN_13: 9781119557616 | ISBN_10: 1119557615
# 332. Machine Learning with Python
#    - Identifiers: ISBN_13: 9783110697254 | ISBN_10: 3110697254
# 333. Introduction to Computing & Problem Solving With PYTHON
#    - Identifiers: ISBN_13: 9789382609810 | ISBN_10: 9382609814
# 334. Python Distilled
#    - Identifiers: ISBN_10: 0134173279 | ISBN_13: 9780134173276
# 335. Test-Driven Development with Python
#    - Identifiers: ISBN_13: 9781491958650 | ISBN_10: 1491958650
# 336. Integrating Python with Leading Computer Forensics Platforms
#    - Identifiers: ISBN_13: 9780128099506 | ISBN_10: 012809950X
# 337. Explorations in Computing
#    - Identifiers: ISBN_13: 9781466572454 | ISBN_10: 1466572450
# 338. Core Java: An Integrated Approach: Covers Concepts, programs and Interview Questions w/CD
#    - Identifiers: ISBN_10: 8177228366 | ISBN_13: 9788177228366
# 339. Clean Code
#    - Identifiers: ISBN_13: 9780136083252 | ISBN_10: 0136083250
# 340. Think DSP
#    - Identifiers: ISBN_13: 9781491938515 | ISBN_10: 149193851X
# 341. Coding Games in Python
#    - Identifiers: ISBN_10: 0606413391 | ISBN_13: 9780606413398
# 342. Learn Python in 7 Days
#    - Identifiers: ISBN_13: 9781787287778 | ISBN_10: 1787287777
# 343. Beginners' Artificial Intelligence and Python Programming
#    - Identifiers: ISBN_13: 9780998401423 | ISBN_10: 0998401420
# 344. Python for MBAs
#    - Identifiers: ISBN_13: 9780231550574 | ISBN_10: 023155057X
# 345. Introduction to Python
#    - Identifiers: ISBN_13: 9781040040669 | ISBN_10: 1040040667
# 346. Python Programming for Raspberry Pi
#    - Identifiers: ISBN_13: 9780789752055 | ISBN_10: 0789752050
# 347. The Rust Programming Language (Covers Rust 2018)
#    - Identifiers: ISBN_13: 9781718500457 | ISBN_10: 1718500459
# 348. Mobile Applications Development
#    - Identifiers: ISBN_10: 311129319X | ISBN_13: 9783111293196
# 349. Object-Oriented Python
#    - Identifiers: ISBN_13: 9781718502062 | ISBN_10: 1718502060
# 350. SKILLFUL MINDS CBSE AI, Coding and Robotics Class 8 Computer Textbook with Fundamentals of Computer | Practical Lab Activities | PictoBlox Jr. Blocks Based of Scratch | Covers Basics of Computer, MS Paint, Algorithmic Thinking
#    - Identifiers: ISBN_13: 9788196940249 | ISBN_10: 8196940246
# 351. Programming and Cybersecurity
#    - Identifiers: ISBN_10: 1801571260 | ISBN_13: 9781801571265
# 352. Neural Network Programming With Python
#    - Identifiers: ISBN_10: 1539381951 | ISBN_13: 9781539381952
# 353. Effective Computation in Physics
#    - Identifiers: ISBN_13: 9781491901588 | ISBN_10: 1491901586
# 354. Learn to Program with Minecraft
#    - Identifiers: ISBN_13: 9781593277451 | ISBN_10: 1593277458
# 355. Python Programming
#    - Identifiers: ISBN_10: 1801116016 | ISBN_13: 9781801116015
# 356. C++ and Python Programming
#    - Identifiers: ISBN_10: 1542834295 | ISBN_13: 9781542834292
# 357. Python GUI Programming Cookbook.
#    - Identifiers: ISBN_10: 1838827544 | ISBN_13: 9781838827540
# 358. Python and XML
#    - Identifiers: ISBN_10: 0596001282 | ISBN_13: 9780596001285
# 359. Web Programming
#    - Identifiers: ISBN_10: 0130410659 | ISBN_13: 9780130410658
# 360. Anticipatory Systems: Humans Meet Artificial Intelligence
#    - Identifiers: ISBN_13: 9782889712885 | ISBN_10: 2889712885
# 361. The Complete Software Developer's Career Guide
#    - Identifiers: ISBN_10: 0999081411 | ISBN_13: 9780999081419
# 362. Think Stats
#    - Identifiers: ISBN_13: 9781491907368 | ISBN_10: 1491907363
# 363. The Python Workbook
#    - Identifiers: ISBN_13: 9783030188733 | ISBN_10: 3030188736
# 364. The Lean Startup
#    - Identifiers: ISBN_13: 9780307887894 | ISBN_10: 0307887898
# 365. Python For Kids For Dummies
#    - Identifiers: ISBN_13: 9781119093107 | ISBN_10: 1119093104
# 366. Discovering Computer Science
#    - Identifiers: ISBN_13: 9781000218466 | ISBN_10: 1000218465
# 367. Hands-On Bitcoin Programming with Python
#    - Identifiers: ISBN_10: 1789537002 | ISBN_13: 9781789537000
# 368. Electronics All-in-One For Dummies
#    - Identifiers: ISBN_13: 9781119320814 | ISBN_10: 111932081X
# 369. Oswaal CBSE Question Bank Class 11 Computer Science, Chapterwise and Topicwise Solved Papers For 2025 Exams
#    - Identifiers: ISBN_13: 9789359582252 | ISBN_10: 9359582255
# 370. Introduction to Computing and Programming in Python
#    - Identifiers: ISBN_13: 9780131176553 | ISBN_10: 0131176552
# 371. Think Bayes
#    - Identifiers: ISBN_13: 9781491945445 | ISBN_10: 1491945443
# 372. Earth Observation Using Python
#    - Identifiers: ISBN_13: 9781119606888 | ISBN_10: 1119606888
# 373. Oxford International AQA Examinations: International GCSE Computer Science
#    - Identifiers: ISBN_13: 9780198417316 | ISBN_10: 0198417314
# 374. Machine Learning for Neuroscience
#    - Identifiers: ISBN_13: 9781000907124 | ISBN_10: 1000907120
# 375. Computer Science and Education
#    - Identifiers: ISBN_13: 9789819924493 | ISBN_10: 9819924499
# 376. Practical OpenCV
#    - Identifiers: ISBN_13: 9781430260806 | ISBN_10: 1430260807
# 377. Raspberry Pi Cookbook
#    - Identifiers: ISBN_13: 9781449365301 | ISBN_10: 1449365302
# 378. Intelligent Computing
#    - Identifiers: ISBN_13: 9783031379635 | ISBN_10: 3031379632
# 379. Jython for Java Programmers
#    - Identifiers: ISBN_10: 0735711119 | ISBN_13: 9780735711112
# 380. BBC Micro:bit in Practice
#    - Identifiers: ISBN_13: 9781804614150 | ISBN_10: 1804614157
# 381. Machine Learning for Computer Scientists and Data Analysts
#    - Identifiers: ISBN_13: 9783030967567 | ISBN_10: 3030967565
# 382. Data Science for Beginners
#    - Identifiers: ISBN_13: 9798788844732
# 383. Internet of Things
#    - Identifiers: ISBN_13: 9789386173591 | ISBN_10: 938617359X
# 384. Introducing Data Science
#    - Identifiers: ISBN_13: 9781638352495 | ISBN_10: 1638352496
# 385. A First Course in Artificial Intelligence
#    - Identifiers: ISBN_13: 9781681088549 | ISBN_10: 1681088541
# 386. Elementary Number Theory in Nine Chapters
#    - Identifiers: ISBN_10: 0521585317 | ISBN_13: 9780521585316
# 387. Introduction to Computation and Programming Using Python
#    - Identifiers: ISBN_10: 1461937159 | ISBN_13: 9781461937159
# 388. An Introduction to Python
#    - Identifiers: ISBN_10: 1906966133 | ISBN_13: 9781906966133
# 389. Programming Pearls
#    - Identifiers: ISBN_13: 9780134498034 | ISBN_10: 0134498038
# 390. Python Object-Oriented Programming
#    - Identifiers: ISBN_13: 9781801075237 | ISBN_10: 1801075239
# 391. 2020 International Conference on Applications and Techniques in Cyber Intelligence
#    - Identifiers: ISBN_13: 9783030539801 | ISBN_10: 3030539806
# 392. Python Programming for Beginners
#    - Identifiers: ISBN_10: 1548987794 | ISBN_13: 9781548987794
# 393. Learn AI with Python
#    - Identifiers: ISBN_13: 9789391392611 | ISBN_10: 939139261X
# 394. Machine Learning With Python
#    - Identifiers: ISBN_10: 1914306104 | ISBN_13: 9781914306105
# 395. Problem Solving with Algorithms and Data Structures Using Python
#    - Identifiers: ISBN_10: 1590282574 | ISBN_13: 9781590282571
# 396. Python for Data Analysis
#    - Identifiers: ISBN_13: 9781491957615 | ISBN_10: 1491957611
# 397. The Python 3 Standard Library by Example
#    - Identifiers: ISBN_10: 0134291050 | ISBN_13: 9780134291055
# 398. Core Python Applications Programming
#    - Identifiers: ISBN_13: 9780132850001 | ISBN_10: 0132850001
# 399. The Python Library Reference
#    - Identifiers: ISBN_10: 1680921584 | ISBN_13: 9781680921588
# 400. Python Machine Learning
#    - Identifiers: ISBN_13: 9798611346952
# 401. Software Engineering
#    - Identifiers: ISBN_10: 9332582696 | ISBN_13: 9789332582699
# 402. Python Succinctly
#    - Identifiers: ISBN_10: 1542827124 | ISBN_13: 9781542827126
# 403. Introduction to Computing and Programming in Python, A Multimedia Approach, Second Edition
#    - Identifiers: ISBN_13: 9780136060277 | ISBN_10: 0136060277
# 404. Learning Robotics Using Python
#    - Identifiers: ISBN_10: 1783287535 | ISBN_13: 9781783287536
# 405. Programming the Raspberry Pi, Second Edition: Getting Started with Python
#    - Identifiers: ISBN_13: 9781259587412 | ISBN_10: 125958741X
# 406. Impractical Python Projects
#    - Identifiers: ISBN_13: 9781593278908 | ISBN_10: 159327890X
# 407. Thinking In C++ (2Nd Edition)
#    - Identifiers: ISBN_13: 9798187522040
# 408. Python High Performance
#    - Identifiers: ISBN_13: 9781787282438 | ISBN_10: 1787282430
# 409. The Agile Comms Handbook
#    - Identifiers: ISBN_10: 173994223X | ISBN_13: 9781739942236
# 410. Raspberry Pi Projects for the Evil Genius
#    - Identifiers: ISBN_13: 9780071819565 | ISBN_10: 0071819568
# 411. Explore Flask
#    - Identifiers: ISBN_10: 0692231358 | ISBN_13: 9780692231357
# 412. Programming the BBC micro:bit: Getting Started with MicroPython
#    - Identifiers: ISBN_13: 9781260117592 | ISBN_10: 1260117596
# 413. Tiny Python Projects
#    - Identifiers: ISBN_13: 9781638350835 | ISBN_10: 1638350833
# 414. Head First Programming
#    - Identifiers: ISBN_13: 9781449389130 | ISBN_10: 1449389139
# 415. PYTHON FLASH CARDS.
#    - Identifiers: ISBN_13: 9781593278960 | ISBN_10: 1593278969
# 416. Must Know High School Computer Programming
#    - Identifiers: ISBN_13: 9781260458473 | ISBN_10: 1260458474
# 417. Machine Learning and Deep Learning Using Python and TensorFlow
#    - Identifiers: ISBN_13: 9781260462302 | ISBN_10: 1260462307
# 418. Practical JRuby on Rails Web 2.0 Projects
#    - Identifiers: ISBN_13: 9781430204190 | ISBN_10: 1430204192
# 419. Django
#    - Identifiers: ISBN_10: 1702723275 | ISBN_13: 9781702723275
# 420. Beginning Programming For Dummies
#    - Identifiers: ISBN_10: 0764549979 | ISBN_13: 9780764549977
# 421. Data-Driven Security
#    - Identifiers: ISBN_13: 9781118793725 | ISBN_10: 1118793722
# 422. Python for Probability, Statistics, and Machine Learning
#    - Identifiers: ISBN_10: 3030185478 | ISBN_13: 9783030185473
# 423. Python® Programming for Dummies®
#    - Identifiers: ISBN_10: 1119488060 | ISBN_13: 9781119488064
# 424. A Practical Guide to Ubuntu Linux
#    - Identifiers: ISBN_13: 9780133927351 | ISBN_10: 0133927350
# 425. A Practical Guide to Fedora and Red Hat Enterprise Linux
#    - Identifiers: ISBN_13: 9780133522174 | ISBN_10: 0133522172
# 426. Starting Out with Python
#    - Identifiers: ISBN_10: 1292225858 | ISBN_13: 9781292225852
# 427. Python for Everyone
#    - Identifiers: ISBN_13: 9781119638292 | ISBN_10: 1119638291
# 428. Red HatRPM Guide
#    - Identifiers: ISBN_10: 0764549650 | ISBN_13: 9780764549656
# 429. The Proceedings of the 2002 Summer Computer Simulation Conference
#    - Identifiers: ISBN_10: 1565552555 | ISBN_13: 9781565552555
# 430. Publishing Python Packages
#    - Identifiers: ISBN_13: 9781638351689 | ISBN_10: 1638351686
# 431. A Functional Start to Computing with Python
#    - Identifiers: ISBN_13: 9781466504554 | ISBN_10: 1466504552
# 432. Arduino and Raspberry Pi Sensor Projects for the Evil Genius
#    - Identifiers: ISBN_13: 9781260010909 | ISBN_10: 1260010902
# 433. SUSE Linux 6.1 Unleashed
#    - Identifiers: ISBN_10: 067231780X | ISBN_13: 9780672317804
# 434. Linux Administration
#    - Identifiers: ISBN_10: 0072225629 | ISBN_13: 9780072225624
# 435. Encyclopedia of Genetics, Genomics, Proteomics and Bioinformatics, 8 Volume Set
#    - Identifiers: ISBN_10: 0470849746 | ISBN_13: 9780470849743
# 436. Tcl and the Tk Toolkit
#    - Identifiers: ISBN_10: 032133633X | ISBN_13: 9780321336330
# 437. Cryptography and Network Security
#    - Identifiers: ISBN_13: 9780136097044 | ISBN_10: 0136097049
# 438. SciPy Programming Succinctly
#    - Identifiers: ISBN_10: 1542809541 | ISBN_13: 9781542809542
# 439. Dirk Gently's Holistic Detective Agency
#    - Identifiers: ISBN_13: 9781476782997 | ISBN_10: 1476782997
# 440. The Art of Computer Programming
#    - Identifiers: ISBN_10: 0201896850 | ISBN_13: 9780201896855
# 441. Red Hat Linux 7.3 Bible
#    - Identifiers: ISBN_10: 0764549413 | ISBN_13: 9780764549410
# 442. Web Application Development with PHP 4.0
#    - Identifiers: ISBN_10: 0735709971 | ISBN_13: 9780735709973
# 443. Red Hat Linux 6.0
#    - Identifiers: ISBN_10: 1888172282 | ISBN_13: 9781888172287
# 444. Astronomical Data Analysis Software and Systems IX
#    - Identifiers: ISBN_10: 1583810471 | ISBN_13: 9781583810477
# 445. Red Hat Linux 6.1
#    - Identifiers: ISBN_10: 1585690201 | ISBN_13: 9781585690206
# 446. MySQL Workbench: Data Modeling & Development
#    - Identifiers: ISBN_13: 9780071791885 | ISBN_10: 0071791884
# 447. Python for Finance
#    - Identifiers: ISBN_10: 1491945362 | ISBN_13: 9781491945360
# 448. Gray Hat Hacking: The Ethical Hacker's Handbook, Sixth Edition
#    - Identifiers: ISBN_13: 9781264268955 | ISBN_10: 1264268955
# 449. Practical C++ Programming
#    - Identifiers: ISBN_13: 9781449367169 | ISBN_10: 144936716X
# 450. Python for DevOps
#    - Identifiers: ISBN_10: 1492057681 | ISBN_13: 9781492057680
# 451. Web Client Programming with Perl
#    - Identifiers: ISBN_10: 156592214X | ISBN_13: 9781565922143
# 452. Designing Data-Intensive Applications
#    - Identifiers: ISBN_10: 1491903066 | ISBN_13: 9781491903063
# 453. Python
#    - Identifiers: ISBN_13: 9780133435153 | ISBN_10: 0133435156
# 454. Mastering Predictive Analytics with scikit-learn and TensorFlow
#    - Identifiers: ISBN_13: 9781789612240 | ISBN_10: 1789612241
# 455. Artificial Intelligence and Machine Learning Fundamentals
#    - Identifiers: ISBN_13: 9781789809206 | ISBN_10: 1789809207
# 456. Hello Web App
#    - Identifiers: ISBN_10: 0986365912 | ISBN_13: 9780986365911
# 457. C++ for Programmers
#    - Identifiers: ISBN_13: 9780471606970 | ISBN_10: 0471606979
# 458. Theory and Applications for Advanced Text Mining
#    - Identifiers: ISBN_13: 9789535108528 | ISBN_10: 9535108522
# 459. JAVASCRIPT in 8 Hours: for Beginners, Learn Coding Fast!
#    - Identifiers: ISBN_13: 9798649767064
# 460. A Beginner's Guide to Coding
#    - Identifiers: ISBN_13: 9781472928641 | ISBN_10: 1472928644
# 461. MicroPython Cookbook
#    - Identifiers: ISBN_10: 1838649956 | ISBN_13: 9781838649951
# 462. Html & Xhtml:Tcr, 4E
#    - Identifiers: ISBN_10: 0070582815 | ISBN_13: 9780070582811

# %%
import requests

# Set up your API key and base URL
API_KEY = 'AIzaSyBa_59ZupTnQEOzwpiXh2w9sQuayhveCcY'
BASE_URL = 'https://www.googleapis.com/books/v1/volumes'

# Function to fetch books based on query and handle pagination
def fetch_books(query, max_results=40, total_books=1000):
    books = []
    start_index = 0
    while len(books) < total_books:
        # Build the URL for the API request
        url = f"{BASE_URL}?q={query}&startIndex={start_index}&maxResults={max_results}&key={API_KEY}"
        response = requests.get(url)
        data = response.json()
        
        # Check if the response contains items
        if data:
            for index, item in enumerate(data.get("items", [])):
                volume_info = item.get('volumeInfo', {})
                sale_info = item.get('saleInfo', {})
                industry_Identifiers = volume_info.get('industryIdentifiers', [])
                book_data = {
                    'book_id' : item.get('id', 'N/A'),  # Book ID
                    'search_key' : query,  # Search key (selfLink is unique)
                    'book_title' : volume_info.get('title', 'N/A'),  # Book title
                    'book_subtitle' : volume_info.get('subtitle', 'N/A'),  # Book subtitle
                    'book_authors' : ', '.join(volume_info.get('authors', ['N/A'])),  # Authors
                    'book_description' : volume_info.get('description', 'No description available.'),  # Description
            
                    # Concatenate all types in industryIdentifiers directly
                    'industryIdentifiers' : ''.join([identifier.get('type', 'N/A') for identifier in industry_Identifiers]),  # Concatenate types
            
                    'text_readingModes' : volume_info.get('readingModes', {}).get('text', 'False'),  # Text reading mode
                    'image_readingModes' : volume_info.get('readingModes', {}).get('image', 'False') , # Image reading mode
                    'pageCount' : volume_info.get('pageCount', '0'),  # Page count
                    'categories' : ', '.join(volume_info.get('categories', ['N/A'])),  # Categories
                    'language' : volume_info.get('language', 'N/A'),  # Language
                    'imageLinks' : volume_info.get('imageLinks', {}).get('thumbnail', 'No thumbnail available.'),  # Image links
                    'ratingsCount' : volume_info.get('ratingsCount', '0'),  # Ratings count
                    'averageRating' : volume_info.get('averageRating', '0'),  # Average rating
                    'country' : volume_info.get('country', 'N/A'),  # Country (publication)
                    'saleability' : sale_info.get('saleability', 'N/A'),  # Saleability
                    'isEbook' : sale_info.get('isEbook', 'False'),  # Is ebook
                    'amount_listPrice' : sale_info.get('listPrice', {}).get('amount', '0.0'),  # Amount listPrice
                    'currencyCode_listPrice' : sale_info.get('listPrice', {}).get('currencyCode', 'N/A'),  # Currency code listPrice
                    'amount_retailPrice' : sale_info.get('retailPrice', {}).get('amount', '0.0'),  # Amount retailPrice
                    'currencyCode_retailPrice' : sale_info.get('retailPrice', {}).get('currencyCode', 'N/A'),  # Currency code retailPrice
                    'buyLink' : volume_info.get('infoLink', 'NA'),  # Buy link
                    'year' : volume_info.get('publishedDate', '0000')[:4],  # Year (from publishedDate)
                    'publisher' : volume_info.get('publisher', 'Not available'),  # Publisher
                }
                books.append(book_data)
        
        # Increment the startIndex for the next page of results
        start_index += max_results
        
        # If no more items, break the loop
        if 'items' not in data or len(data['items']) == 0:
            break
    
    return books

# Example usage
query = 'python'
books = fetch_books(query)

# Display the first few books
for book in books[:5]:
    print(book)
# Out:
# {'book_id': 'pVP8AQAAQBAJ', 'search_key': 'python', 'book_title': 'Introduction to Computation and Programming Using Python', 'book_subtitle': 'N/A', 'book_authors': 'John V. Guttag, John Guttag', 'book_description': 'An introductory text that teaches students the art of computational problem solving, covering topics that range from simple algorithms to information visualization.', 'industryIdentifiers': 'ISBN_13ISBN_10', 'text_readingModes': False, 'image_readingModes': True, 'pageCount': 315, 'categories': 'Computers', 'language': 'en', 'imageLinks': 'http://books.google.com/books/content?id=pVP8AQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'ratingsCount': '0', 'averageRating': '0', 'country': 'N/A', 'saleability': 'NOT_FOR_SALE', 'isEbook': False, 'amount_listPrice': '0.0', 'currencyCode_listPrice': 'N/A', 'amount_retailPrice': '0.0', 'currencyCode_retailPrice': 'N/A', 'buyLink': 'http://books.google.co.in/books?id=pVP8AQAAQBAJ&dq=python&hl=&source=gbs_api', 'year': '2013', 'publisher': 'MIT Press'}
# {'book_id': 'HFeGvgEACAAJ', 'search_key': 'python', 'book_title': 'The Quick Python Book', 'book_subtitle': 'N/A', 'book_authors': 'Vernon L. Ceder, Naomi R. Ceder', 'book_description': "Introduces the programming language's syntax, control flow, and basic data structures and covers its interaction with applications and mangement of large collections of code.", 'industryIdentifiers': 'ISBN_10ISBN_13', 'text_readingModes': False, 'image_readingModes': False, 'pageCount': 336, 'categories': 'Computers', 'language': 'en', 'imageLinks': 'http://books.google.com/books/content?id=HFeGvgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'ratingsCount': '0', 'averageRating': '0', 'country': 'N/A', 'saleability': 'NOT_FOR_SALE', 'isEbook': False, 'amount_listPrice': '0.0', 'currencyCode_listPrice': 'N/A', 'amount_retailPrice': '0.0', 'currencyCode_retailPrice': 'N/A', 'buyLink': 'http://books.google.co.in/books?id=HFeGvgEACAAJ&dq=python&hl=&source=gbs_api', 'year': '2010', 'publisher': 'Manning Publications Company'}
# {'book_id': 'nEJ-jcYF2fMC', 'search_key': 'python', 'book_title': 'Learning Python', 'book_subtitle': 'N/A', 'book_authors': 'Mark Lutz', 'book_description': "Portable, powerful, and a breeze to use, Python is ideal for both standalone programs and scripting applications. With this hands-on book, you can master the fundamentals of the core Python language quickly and efficiently, whether you're new to programming or just new to Python. Once you finish, you will know enough about the language to use it in any application domain you choose. Learning Python is based on material from author Mark Lutz's popular training courses, which he's taught over the past decade. Each chapter is a self-contained lesson that helps you thoroughly understand a key component of Python before you continue. Along with plenty of annotated examples, illustrations, and chapter summaries, every chapter also contains Brain Builder, a unique section with practical exercises and review quizzes that let you practice new skills and test your understanding as you go. This book covers: Types and Operations -- Python's major built-in object types in depth: numbers, lists, dictionaries, and more Statements and Syntax -- the code you type to create and process objects in Python, along with Python's general syntax model Functions -- Python's basic procedural tool for structuring and reusing code Modules -- packages of statements, functions, and other tools organized into larger components Classes and OOP -- Python's optional object-oriented programming tool for structuring code for customization and reuse Exceptions and Tools -- exception handling model and statements, plus a look at development tools for writing larger programs Learning Python gives you a deep and complete understanding of the language that will help you comprehend any application-level examples of Python that you later encounter. If you're ready to discover what Google and YouTube see in Python, this book is the best way to get started.", 'industryIdentifiers': 'ISBN_13ISBN_10', 'text_readingModes': True, 'image_readingModes': True, 'pageCount': 749, 'categories': 'Computers', 'language': 'en', 'imageLinks': 'http://books.google.com/books/content?id=nEJ-jcYF2fMC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'ratingsCount': 26, 'averageRating': 4, 'country': 'N/A', 'saleability': 'FOR_SALE', 'isEbook': True, 'amount_listPrice': 3235.55, 'currencyCode_listPrice': 'INR', 'amount_retailPrice': 3235.55, 'currencyCode_retailPrice': 'INR', 'buyLink': 'https://play.google.com/store/books/details?id=nEJ-jcYF2fMC&source=gbs_api', 'year': '2007', 'publisher': '"O\'Reilly Media, Inc."'}
# {'book_id': '4pgQfXQvekcC', 'search_key': 'python', 'book_title': 'Learning Python', 'book_subtitle': 'Powerful Object-Oriented Programming', 'book_authors': 'Mark Lutz', 'book_description': 'Get a comprehensive, in-depth introduction to the core Python language with this hands-on book. Based on author Mark Lutz’s popular training course, this updated fifth edition will help you quickly write efficient, high-quality code with Python. It’s an ideal way to begin, whether you’re new to programming or a professional developer versed in other languages. Complete with quizzes, exercises, and helpful illustrations, this easy-to-follow, self-paced tutorial gets you started with both Python 2.7 and 3.3— the latest releases in the 3.X and 2.X lines—plus all other releases in common use today. You’ll also learn some advanced language features that recently have become more common in Python code. Explore Python’s major built-in object types such as numbers, lists, and dictionaries Create and process objects with Python statements, and learn Python’s general syntax model Use functions to avoid code redundancy and package code for reuse Organize statements, functions, and other tools into larger components with modules Dive into classes: Python’s object-oriented programming tool for structuring code Write large programs with Python’s exception-handling model and development tools Learn advanced Python tools, including decorators, descriptors, metaclasses, and Unicode processing', 'industryIdentifiers': 'ISBN_13ISBN_10', 'text_readingModes': True, 'image_readingModes': True, 'pageCount': 1740, 'categories': 'Computers', 'language': 'en', 'imageLinks': 'http://books.google.com/books/content?id=4pgQfXQvekcC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'ratingsCount': 4, 'averageRating': 3.5, 'country': 'N/A', 'saleability': 'FOR_SALE', 'isEbook': True, 'amount_listPrice': 3540, 'currencyCode_listPrice': 'INR', 'amount_retailPrice': 3540, 'currencyCode_retailPrice': 'INR', 'buyLink': 'https://play.google.com/store/books/details?id=4pgQfXQvekcC&source=gbs_api', 'year': '2013', 'publisher': '"O\'Reilly Media, Inc."'}
# {'book_id': 'bIZHCgAAQBAJ', 'search_key': 'python', 'book_title': 'Fluent Python', 'book_subtitle': 'Clear, Concise, and Effective Programming', 'book_authors': 'Luciano Ramalho', 'book_description': 'Python’s simplicity lets you become productive quickly, but this often means you aren’t using everything it has to offer. With this hands-on guide, you’ll learn how to write effective, idiomatic Python code by leveraging its best—and possibly most neglected—features. Author Luciano Ramalho takes you through Python’s core language features and libraries, and shows you how to make your code shorter, faster, and more readable at the same time. Many experienced programmers try to bend Python to fit patterns they learned from other languages, and never discover Python features outside of their experience. With this book, those Python programmers will thoroughly learn how to become proficient in Python 3. This book covers: Python data model: understand how special methods are the key to the consistent behavior of objects Data structures: take full advantage of built-in types, and understand the text vs bytes duality in the Unicode age Functions as objects: view Python functions as first-class objects, and understand how this affects popular design patterns Object-oriented idioms: build classes by learning about references, mutability, interfaces, operator overloading, and multiple inheritance Control flow: leverage context managers, generators, coroutines, and concurrency with the concurrent.futures and asyncio packages Metaprogramming: understand how properties, attribute descriptors, class decorators, and metaclasses work', 'industryIdentifiers': 'ISBN_13ISBN_10', 'text_readingModes': True, 'image_readingModes': True, 'pageCount': 755, 'categories': 'Computers', 'language': 'en', 'imageLinks': 'http://books.google.com/books/content?id=bIZHCgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'ratingsCount': 2, 'averageRating': 5, 'country': 'N/A', 'saleability': 'NOT_FOR_SALE', 'isEbook': False, 'amount_listPrice': '0.0', 'currencyCode_listPrice': 'N/A', 'amount_retailPrice': '0.0', 'currencyCode_retailPrice': 'N/A', 'buyLink': 'http://books.google.co.in/books?id=bIZHCgAAQBAJ&dq=python&hl=&source=gbs_api', 'year': '2015', 'publisher': '"O\'Reilly Media, Inc."'}

# %%
import pandas as pd
df1 = pd.DataFrame(books)
df1
# Out:
#           book_id search_key  \
# 0    pVP8AQAAQBAJ     python
# 1    HFeGvgEACAAJ     python
# 2    nEJ-jcYF2fMC     python
# 3    4pgQfXQvekcC     python
# 4    bIZHCgAAQBAJ     python
# ..            ...        ...
# 702  WJy1zQEACAAJ     python
# 703  GDia0Uy3D3cC     python
# 704  BE0EAAAAMBAJ     python
# 705  kDgDAAAAMBAJ     python
# 706  I_QDAAAAMBAJ     python
#
#                                             book_title  \
# 0    Introduction to Computation and Programming Us...
# 1                                The Quick Python Book
# 2                                      Learning Python
# 3                                      Learning Python
# 4                                        Fluent Python
# ..                                                 ...
# 702  JAVASCRIPT in 8 Hours: for Beginners, Learn Co...
# 703  Totemism and Exogamy: -3. An ethnographical su...
# 704                                               LIFE
# 705                                                Jet
# 706                                  Weekly World News
#
#                                  book_subtitle  \
# 0                                          N/A
# 1                                          N/A
# 2                                          N/A
# 3         Powerful Object-Oriented Programming
# 4    Clear, Concise, and Effective Programming
# ..                                         ...
# 702                                        N/A
# 703                                        N/A
# 704                                        N/A
# 705                                        N/A
# 706                                        N/A
#
#                         book_authors  \
# 0        John V. Guttag, John Guttag
# 1    Vernon L. Ceder, Naomi R. Ceder
# 2                          Mark Lutz
# 3                          Mark Lutz
# 4                    Luciano Ramalho
# ..                               ...
# 702                          Ray Yao
# 703              James George Frazer
# 704                              N/A
# 705                              N/A
# 706                              N/A
#
#                                       book_description industryIdentifiers  \
# 0    An introductory text that teaches students the...      ISBN_13ISBN_10
# 1    Introduces the programming language's syntax, ...      ISBN_10ISBN_13
# 2    Portable, powerful, and a breeze to use, Pytho...      ISBN_13ISBN_10
# 3    Get a comprehensive, in-depth introduction to ...      ISBN_13ISBN_10
# 4    Python’s simplicity lets you become productive...      ISBN_13ISBN_10
# ..                                                 ...                 ...
# 702  About this book: Absolutely for Beginners "Jav...             ISBN_13
# 703                          No description available.               OTHER
# 704  LIFE Magazine is the treasured photographic ma...
# 705  The weekly source of African American politica...
# 706  Rooted in the creative success of over 30 year...
#
#      text_readingModes  image_readingModes pageCount  ... country  \
# 0                False                True       315  ...     N/A
# 1                False               False       336  ...     N/A
# 2                 True                True       749  ...     N/A
# 3                 True                True      1740  ...     N/A
# 4                 True                True       755  ...     N/A
# ..                 ...                 ...       ...  ...     ...
# 702              False               False       200  ...     N/A
# 703              False               False       674  ...     N/A
# 704              False                True       152  ...     N/A
# 705              False                True        64  ...     N/A
# 706              False                True        44  ...     N/A
#
#       saleability isEbook amount_listPrice currencyCode_listPrice  \
# 0    NOT_FOR_SALE   False              0.0                    N/A
# 1    NOT_FOR_SALE   False              0.0                    N/A
# 2        FOR_SALE    True          3235.55                    INR
# 3        FOR_SALE    True             3540                    INR
# 4    NOT_FOR_SALE   False              0.0                    N/A
# ..            ...     ...              ...                    ...
# 702  NOT_FOR_SALE   False              0.0                    N/A
# 703  NOT_FOR_SALE   False              0.0                    N/A
# 704  NOT_FOR_SALE   False              0.0                    N/A
# 705  NOT_FOR_SALE   False              0.0                    N/A
# 706  NOT_FOR_SALE   False              0.0                    N/A
#
#     amount_retailPrice currencyCode_retailPrice  \
# 0                  0.0                      N/A
# 1                  0.0                      N/A
# 2              3235.55                      INR
# 3                 3540                      INR
# 4                  0.0                      N/A
# ..                 ...                      ...
# 702                0.0                      N/A
# 703                0.0                      N/A
# 704                0.0                      N/A
# 705                0.0                      N/A
# 706                0.0                      N/A
#
#                                                buyLink  year  \
# 0    http://books.google.co.in/books?id=pVP8AQAAQBA...  2013
# 1    http://books.google.co.in/books?id=HFeGvgEACAA...  2010
# 2    https://play.google.com/store/books/details?id...  2007
# 3    https://play.google.com/store/books/details?id...  2013
# 4    http://books.google.co.in/books?id=bIZHCgAAQBA...  2015
# ..                                                 ...   ...
# 702  http://books.google.co.in/books?id=WJy1zQEACAA...  2020
# 703  http://books.google.co.in/books?id=GDia0Uy3D3c...  1910
# 704  http://books.google.co.in/books?id=BE0EAAAAMBA...  1950
# 705  http://books.google.co.in/books?id=kDgDAAAAMBA...  1996
# 706  http://books.google.co.in/books?id=I_QDAAAAMBA...  1991
#
#                         publisher
# 0                       MIT Press
# 1    Manning Publications Company
# 2          "O'Reilly Media, Inc."
# 3          "O'Reilly Media, Inc."
# 4          "O'Reilly Media, Inc."
# ..                            ...
# 702                 Not available
# 703                 Not available
# 704                 Not available
# 705                 Not available
# 706                 Not available
#
# [707 rows x 25 columns]

# %%
import requests

# Set up your API key and base URL
API_KEY = 'AIzaSyBa_59ZupTnQEOzwpiXh2w9sQuayhveCcY'
BASE_URL = 'https://www.googleapis.com/books/v1/volumes'

# Function to fetch books based on query and handle pagination
def fetch_books(query, max_results=40, total_books=1000):
    books = []
    start_index = 0
    while len(books) < total_books:
        # Build the URL for the API request
        url = f"{BASE_URL}?q={query}&startIndex={start_index}&maxResults={max_results}&key={API_KEY}"
        response = requests.get(url)
        data = response.json()
        
        # Check if the response contains items
        if data:
            for index, item in enumerate(data.get("items", [])):
                volume_info = item.get('volumeInfo', {})
                sale_info = item.get('saleInfo', {})
                industry_Identifiers = volume_info.get('industryIdentifiers', [])
                book_data = {
                    'book_id' : item.get('id', 'N/A'),  # Book ID
                    'search_key' : query,  # Search key (selfLink is unique)
                    'book_title' : volume_info.get('title', 'N/A'),  # Book title
                    'book_subtitle' : volume_info.get('subtitle', 'N/A'),  # Book subtitle
                    'book_authors' : ', '.join(volume_info.get('authors', ['N/A'])),  # Authors
                    'book_description' : volume_info.get('description', 'No description available.'),  # Description
            
                    # Concatenate all types in industryIdentifiers directly
                    'industryIdentifiers' : ''.join([identifier.get('type', 'N/A') for identifier in industry_Identifiers]),  # Concatenate types
            
                    'text_readingModes' : volume_info.get('readingModes', {}).get('text', 'False'),  # Text reading mode
                    'image_readingModes' : volume_info.get('readingModes', {}).get('image', 'False') , # Image reading mode
                    'pageCount' : volume_info.get('pageCount', '0'),  # Page count
                    'categories' : ', '.join(volume_info.get('categories', ['N/A'])),  # Categories
                    'language' : volume_info.get('language', 'N/A'),  # Language
                    'imageLinks' : volume_info.get('imageLinks', {}).get('thumbnail', 'No thumbnail available.'),  # Image links
                    'ratingsCount' : volume_info.get('ratingsCount', '0'),  # Ratings count
                    'averageRating' : volume_info.get('averageRating', '0'),  # Average rating
                    'country' : volume_info.get('country', 'N/A'),  # Country (publication)
                    'saleability' : sale_info.get('saleability', 'N/A'),  # Saleability
                    'isEbook' : sale_info.get('isEbook', 'False'),  # Is ebook
                    'amount_listPrice' : sale_info.get('listPrice', {}).get('amount', '0.0'),  # Amount listPrice
                    'currencyCode_listPrice' : sale_info.get('listPrice', {}).get('currencyCode', 'N/A'),  # Currency code listPrice
                    'amount_retailPrice' : sale_info.get('retailPrice', {}).get('amount', '0.0'),  # Amount retailPrice
                    'currencyCode_retailPrice' : sale_info.get('retailPrice', {}).get('currencyCode', 'N/A'),  # Currency code retailPrice
                    'buyLink' : volume_info.get('infoLink', 'NA'),  # Buy link
                    'year' : volume_info.get('publishedDate', '0000')[:4],  # Year (from publishedDate)
                    'publisher' : volume_info.get('publisher', 'Not available'),  # Publisher
                }
                books.append(book_data)
        
        # Increment the startIndex for the next page of results
        start_index += max_results
        
        # If no more items, break the loop
        if 'items' not in data or len(data['items']) == 0:
            break
    
    return books

# Example usage
query = 'sql'
books = fetch_books(query)

# Display the first few books
for book in books[:5]:
    print(book)
# Out:
# {'book_id': 'y3_9EAAAQBAJ', 'search_key': 'sql', 'book_title': 'SQL All-in-One For Dummies', 'book_subtitle': 'N/A', 'book_authors': 'Allen G. Taylor, Richard Blum', 'book_description': 'The most thorough SQL reference, now updated for SQL:2023 SQL All-in-One For Dummies has everything you need to get started with the SQL programming language, and then to level up your skill with advanced applications. This relational database coding language is one of the most used languages in professional software development. And, as it becomes ever more important to take control of data, there’s no end in sight to the need for SQL know-how. You can take your career to the next level with this guide to creating databases, accessing and editing data, protecting data from corruption, and integrating SQL with other languages in a programming environment. Become a SQL guru and turn the page on the next chapter of your coding career. Get 7 mini-books in one, covering basic SQL, database development, and advanced SQL concepts Read clear explanations of SQL code and learn to write complex queries Discover how to apply SQL in real-world situations to gain control over large datasets Enjoy a thorough reference to common tasks and issues in SQL development This Dummies All-in-One guide is for all SQL users—from beginners to more experienced programmers. Find the info and the examples you need to reach the next stage in your SQL journey.', 'industryIdentifiers': 'ISBN_13ISBN_10', 'text_readingModes': True, 'image_readingModes': True, 'pageCount': 807, 'categories': 'Computers', 'language': 'en', 'imageLinks': 'http://books.google.com/books/content?id=y3_9EAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'ratingsCount': '0', 'averageRating': '0', 'country': 'N/A', 'saleability': 'FOR_SALE', 'isEbook': True, 'amount_listPrice': 706.82, 'currencyCode_listPrice': 'INR', 'amount_retailPrice': 353.41, 'currencyCode_retailPrice': 'INR', 'buyLink': 'https://play.google.com/store/books/details?id=y3_9EAAAQBAJ&source=gbs_api', 'year': '2024', 'publisher': 'John Wiley & Sons'}
# {'book_id': 'pjhCEAAAQBAJ', 'search_key': 'sql', 'book_title': 'SQL for Data Analysis', 'book_subtitle': 'N/A', 'book_authors': 'Cathy Tanimura', 'book_description': "With the explosion of data, computing power, and cloud data warehouses, SQL has become an even more indispensable tool for the savvy analyst or data scientist. This practical book reveals new and hidden ways to improve your SQL skills, solve problems, and make the most of SQL as part of your workflow. You'll learn how to use both common and exotic SQL functions such as joins, window functions, subqueries, and regular expressions in new, innovative ways--as well as how to combine SQL techniques to accomplish your goals faster, with understandable code. If you work with SQL databases, this is a must-have reference. Learn the key steps for preparing your data for analysis Perform time series analysis using SQL's date and time manipulations Use cohort analysis to investigate how groups change over time Use SQL's powerful functions and operators for text analysis Detect outliers in your data and replace them with alternate values Establish causality using experiment analysis, also known as A/B testing", 'industryIdentifiers': 'ISBN_13ISBN_10', 'text_readingModes': False, 'image_readingModes': True, 'pageCount': 359, 'categories': 'Computers', 'language': 'en', 'imageLinks': 'http://books.google.com/books/content?id=pjhCEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'ratingsCount': '0', 'averageRating': '0', 'country': 'N/A', 'saleability': 'NOT_FOR_SALE', 'isEbook': False, 'amount_listPrice': '0.0', 'currencyCode_listPrice': 'N/A', 'amount_retailPrice': '0.0', 'currencyCode_retailPrice': 'N/A', 'buyLink': 'http://books.google.co.in/books?id=pjhCEAAAQBAJ&dq=sql&hl=&source=gbs_api', 'year': '2021', 'publisher': '"O\'Reilly Media, Inc."'}
# {'book_id': 'BA2CDwAAQBAJ', 'search_key': 'sql', 'book_title': '1000 SQL Interview Questions and Answers', 'book_subtitle': '1000 most important and frequently asked structured query language questions and answers to crack interviews', 'book_authors': 'Vamsee Puligadda', 'book_description': "Get that job, you aspire for! Want to switch to that high paying job? Or are you already been preparing hard to give interview the next weekend? Do you know how many people get rejected in interviews by preparing only concepts but not focusing on actually which questions will be asked in the interview? Don't be that person this time. This is the most comprehensive Structured Query Language (SQL) interview questions book that you can ever find out. It contains: 1000 most frequently asked and important SQL interview questions and answers Wide range of questions which cover not only basics in SQL but also most advanced and complex questions which will help freshers, experienced professionals, senior developers, testers to crack their interviews.", 'industryIdentifiers': '', 'text_readingModes': False, 'image_readingModes': True, 'pageCount': 189, 'categories': 'Computers', 'language': 'en', 'imageLinks': 'http://books.google.com/books/content?id=BA2CDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'ratingsCount': '0', 'averageRating': '0', 'country': 'N/A', 'saleability': 'FOR_SALE', 'isEbook': True, 'amount_listPrice': 206.5, 'currencyCode_listPrice': 'INR', 'amount_retailPrice': 144.55, 'currencyCode_retailPrice': 'INR', 'buyLink': 'https://play.google.com/store/books/details?id=BA2CDwAAQBAJ&source=gbs_api', 'year': '0000', 'publisher': 'Vamsee Puligadda'}
# {'book_id': 'RHOOCwAAQBAJ', 'search_key': 'sql', 'book_title': 'Getting Started with SQL', 'book_subtitle': 'N/A', 'book_authors': 'Thomas Nield', 'book_description': 'Businesses are gathering data today at exponential rates and yet few people know how to access it meaningfully. If you’re a business or IT professional, this short hands-on guide teaches you how to pull and transform data with SQL in significant ways. You will quickly master the fundamentals of SQL and learn how to create your own databases. Author Thomas Nield provides exercises throughout the book to help you practice your newfound SQL skills at home, without having to use a database server environment. Not only will you learn how to use key SQL statements to find and manipulate your data, but you’ll also discover how to efficiently design and manage databases to meet your needs. You’ll also learn how to: Explore relational databases, including lightweight and centralized models Use SQLite and SQLiteStudio to create lightweight databases in minutes Query and transform data in meaningful ways by using SELECT, WHERE, GROUP BY, and ORDER BY Join tables to get a more complete view of your business data Build your own tables and centralized databases by using normalized design principles Manage data by learning how to INSERT, DELETE, and UPDATE records', 'industryIdentifiers': 'ISBN_13ISBN_10', 'text_readingModes': True, 'image_readingModes': True, 'pageCount': 144, 'categories': 'Computers', 'language': 'en', 'imageLinks': 'http://books.google.com/books/content?id=RHOOCwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'ratingsCount': '0', 'averageRating': '0', 'country': 'N/A', 'saleability': 'FOR_SALE', 'isEbook': True, 'amount_listPrice': 2135.8, 'currencyCode_listPrice': 'INR', 'amount_retailPrice': 2135.8, 'currencyCode_retailPrice': 'INR', 'buyLink': 'https://play.google.com/store/books/details?id=RHOOCwAAQBAJ&source=gbs_api', 'year': '2016', 'publisher': '"O\'Reilly Media, Inc."'}
# {'book_id': 'FwKHDwAAQBAJ', 'search_key': 'sql', 'book_title': 'Learning SQL', 'book_subtitle': 'Master SQL Fundamentals', 'book_authors': 'Alan Beaulieu', 'book_description': "Updated for the latest database management systems -- including MySQL 6.0, Oracle 11g, and Microsoft's SQL Server 2008 -- this introductory guide will get you up and running with SQL quickly. Whether you need to write database applications, perform administrative tasks, or generate reports, Learning SQL, Second Edition, will help you easily master all the SQL fundamentals. Each chapter presents a self-contained lesson on a key SQL concept or technique, with numerous illustrations and annotated examples. Exercises at the end of each chapter let you practice the skills you learn. With this book, you will: Move quickly through SQL basics and learn several advanced features Use SQL data statements to generate, manipulate, and retrieve data Create database objects, such as tables, indexes, and constraints, using SQL schema statements Learn how data sets interact with queries, and understand the importance of subqueries Convert and manipulate data with SQL's built-in functions, and use conditional logic in data statements Knowledge of SQL is a must for interacting with data. With Learning SQL, you'll quickly learn how to put the power and flexibility of this language to work.", 'industryIdentifiers': 'ISBN_13ISBN_10', 'text_readingModes': False, 'image_readingModes': True, 'pageCount': 338, 'categories': 'Computers', 'language': 'en', 'imageLinks': 'http://books.google.com/books/content?id=FwKHDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'ratingsCount': '0', 'averageRating': '0', 'country': 'N/A', 'saleability': 'NOT_FOR_SALE', 'isEbook': False, 'amount_listPrice': '0.0', 'currencyCode_listPrice': 'N/A', 'amount_retailPrice': '0.0', 'currencyCode_retailPrice': 'N/A', 'buyLink': 'http://books.google.co.in/books?id=FwKHDwAAQBAJ&dq=sql&hl=&source=gbs_api', 'year': '2009', 'publisher': "O'Reilly Media"}

# %%
import pandas as pd
df2 = pd.DataFrame(books)
df2
# Out:
#           book_id search_key  \
# 0    y3_9EAAAQBAJ        sql
# 1    pjhCEAAAQBAJ        sql
# 2    BA2CDwAAQBAJ        sql
# 3    RHOOCwAAQBAJ        sql
# 4    FwKHDwAAQBAJ        sql
# ..            ...        ...
# 670  Fms3AQAAMAAJ        sql
# 671  -1gfAQAAMAAJ        sql
# 672  WStqa-OykF0C        sql
# 673  E1EEAAAAMBAJ        sql
# 674  1RRBAQAAMAAJ        sql
#
#                                             book_title  \
# 0                           SQL All-in-One For Dummies
# 1                                SQL for Data Analysis
# 2             1000 SQL Interview Questions and Answers
# 3                             Getting Started with SQL
# 4                                         Learning SQL
# ..                                                 ...
# 670                                       De Ingenieur
# 671                                 Marine Engineering
# 672  Muret-Sanders Enzyklopädisches englisch-deutsc...
# 673                                          InfoWorld
# 674                                               JMPA
#
#                                          book_subtitle  \
# 0                                                  N/A
# 1                                                  N/A
# 2    1000 most important and frequently asked struc...
# 3                                                  N/A
# 4                              Master SQL Fundamentals
# ..                                                 ...
# 670                                                N/A
# 671                                                N/A
# 672                                                N/A
# 673                                                N/A
# 674                                                N/A
#
#                       book_authors  \
# 0    Allen G. Taylor, Richard Blum
# 1                   Cathy Tanimura
# 2                 Vamsee Puligadda
# 3                     Thomas Nield
# 4                    Alan Beaulieu
# ..                             ...
# 670                            N/A
# 671                            N/A
# 672                   Eduard Muret
# 673                            N/A
# 674                            N/A
#
#                                       book_description industryIdentifiers  \
# 0    The most thorough SQL reference, now updated f...      ISBN_13ISBN_10
# 1    With the explosion of data, computing power, a...      ISBN_13ISBN_10
# 2    Get that job, you aspire for! Want to switch t...
# 3    Businesses are gathering data today at exponen...      ISBN_13ISBN_10
# 4    Updated for the latest database management sys...      ISBN_13ISBN_10
# ..                                                 ...                 ...
# 670                          No description available.               OTHER
# 671                          No description available.               OTHER
# 672                          No description available.               OTHER
# 673  InfoWorld is targeted to Senior IT professiona...
# 674                          No description available.               OTHER
#
#      text_readingModes  image_readingModes pageCount  ... country  \
# 0                 True                True       807  ...     N/A
# 1                False                True       359  ...     N/A
# 2                False                True       189  ...     N/A
# 3                 True                True       144  ...     N/A
# 4                False                True       338  ...     N/A
# ..                 ...                 ...       ...  ...     ...
# 670              False               False      1018  ...     N/A
# 671              False               False      1146  ...     N/A
# 672              False               False      1172  ...     N/A
# 673              False                True       156  ...     N/A
# 674              False                True       872  ...     N/A
#
#       saleability isEbook amount_listPrice currencyCode_listPrice  \
# 0        FOR_SALE    True           706.82                    INR
# 1    NOT_FOR_SALE   False              0.0                    N/A
# 2        FOR_SALE    True            206.5                    INR
# 3        FOR_SALE    True           2135.8                    INR
# 4    NOT_FOR_SALE   False              0.0                    N/A
# ..            ...     ...              ...                    ...
# 670  NOT_FOR_SALE   False              0.0                    N/A
# 671  NOT_FOR_SALE   False              0.0                    N/A
# 672  NOT_FOR_SALE   False              0.0                    N/A
# 673  NOT_FOR_SALE   False              0.0                    N/A
# 674          FREE    True              0.0                    N/A
#
#     amount_retailPrice currencyCode_retailPrice  \
# 0               353.41                      INR
# 1                  0.0                      N/A
# 2               144.55                      INR
# 3               2135.8                      INR
# 4                  0.0                      N/A
# ..                 ...                      ...
# 670                0.0                      N/A
# 671                0.0                      N/A
# 672                0.0                      N/A
# 673                0.0                      N/A
# 674                0.0                      N/A
#
#                                                buyLink  year  \
# 0    https://play.google.com/store/books/details?id...  2024
# 1    http://books.google.co.in/books?id=pjhCEAAAQBA...  2021
# 2    https://play.google.com/store/books/details?id...  0000
# 3    https://play.google.com/store/books/details?id...  2016
# 4    http://books.google.co.in/books?id=FwKHDwAAQBA...  2009
# ..                                                 ...   ...
# 670  http://books.google.co.in/books?id=Fms3AQAAMAA...  1917
# 671  http://books.google.co.in/books?id=-1gfAQAAMAA...  1921
# 672  http://books.google.co.in/books?id=WStqa-OykF0...  1910
# 673  http://books.google.co.in/books?id=E1EEAAAAMBA...  1998
# 674  https://play.google.com/store/books/details?id...  1881
#
#                   publisher
# 0         John Wiley & Sons
# 1    "O'Reilly Media, Inc."
# 2          Vamsee Puligadda
# 3    "O'Reilly Media, Inc."
# 4            O'Reilly Media
# ..                      ...
# 670           Not available
# 671           Not available
# 672           Not available
# 673           Not available
# 674           Not available
#
# [675 rows x 25 columns]

# %%
df = pd.concat([df1, df2], axis=0, ignore_index=True)
df
# Out:
#            book_id search_key  \
# 0     pVP8AQAAQBAJ     python
# 1     HFeGvgEACAAJ     python
# 2     nEJ-jcYF2fMC     python
# 3     4pgQfXQvekcC     python
# 4     bIZHCgAAQBAJ     python
# ...            ...        ...
# 1377  Fms3AQAAMAAJ        sql
# 1378  -1gfAQAAMAAJ        sql
# 1379  WStqa-OykF0C        sql
# 1380  E1EEAAAAMBAJ        sql
# 1381  1RRBAQAAMAAJ        sql
#
#                                              book_title  \
# 0     Introduction to Computation and Programming Us...
# 1                                 The Quick Python Book
# 2                                       Learning Python
# 3                                       Learning Python
# 4                                         Fluent Python
# ...                                                 ...
# 1377                                       De Ingenieur
# 1378                                 Marine Engineering
# 1379  Muret-Sanders Enzyklopädisches englisch-deutsc...
# 1380                                          InfoWorld
# 1381                                               JMPA
#
#                                   book_subtitle  \
# 0                                           N/A
# 1                                           N/A
# 2                                           N/A
# 3          Powerful Object-Oriented Programming
# 4     Clear, Concise, and Effective Programming
# ...                                         ...
# 1377                                        N/A
# 1378                                        N/A
# 1379                                        N/A
# 1380                                        N/A
# 1381                                        N/A
#
#                          book_authors  \
# 0         John V. Guttag, John Guttag
# 1     Vernon L. Ceder, Naomi R. Ceder
# 2                           Mark Lutz
# 3                           Mark Lutz
# 4                     Luciano Ramalho
# ...                               ...
# 1377                              N/A
# 1378                              N/A
# 1379                     Eduard Muret
# 1380                              N/A
# 1381                              N/A
#
#                                        book_description industryIdentifiers  \
# 0     An introductory text that teaches students the...      ISBN_13ISBN_10
# 1     Introduces the programming language's syntax, ...      ISBN_10ISBN_13
# 2     Portable, powerful, and a breeze to use, Pytho...      ISBN_13ISBN_10
# 3     Get a comprehensive, in-depth introduction to ...      ISBN_13ISBN_10
# 4     Python’s simplicity lets you become productive...      ISBN_13ISBN_10
# ...                                                 ...                 ...
# 1377                          No description available.               OTHER
# 1378                          No description available.               OTHER
# 1379                          No description available.               OTHER
# 1380  InfoWorld is targeted to Senior IT professiona...
# 1381                          No description available.               OTHER
#
#       text_readingModes  image_readingModes pageCount  ... country  \
# 0                 False                True       315  ...     N/A
# 1                 False               False       336  ...     N/A
# 2                  True                True       749  ...     N/A
# 3                  True                True      1740  ...     N/A
# 4                  True                True       755  ...     N/A
# ...                 ...                 ...       ...  ...     ...
# 1377              False               False      1018  ...     N/A
# 1378              False               False      1146  ...     N/A
# 1379              False               False      1172  ...     N/A
# 1380              False                True       156  ...     N/A
# 1381              False                True       872  ...     N/A
#
#        saleability isEbook amount_listPrice currencyCode_listPrice  \
# 0     NOT_FOR_SALE   False              0.0                    N/A
# 1     NOT_FOR_SALE   False              0.0                    N/A
# 2         FOR_SALE    True          3235.55                    INR
# 3         FOR_SALE    True             3540                    INR
# 4     NOT_FOR_SALE   False              0.0                    N/A
# ...            ...     ...              ...                    ...
# 1377  NOT_FOR_SALE   False              0.0                    N/A
# 1378  NOT_FOR_SALE   False              0.0                    N/A
# 1379  NOT_FOR_SALE   False              0.0                    N/A
# 1380  NOT_FOR_SALE   False              0.0                    N/A
# 1381          FREE    True              0.0                    N/A
#
#      amount_retailPrice currencyCode_retailPrice  \
# 0                   0.0                      N/A
# 1                   0.0                      N/A
# 2               3235.55                      INR
# 3                  3540                      INR
# 4                   0.0                      N/A
# ...                 ...                      ...
# 1377                0.0                      N/A
# 1378                0.0                      N/A
# 1379                0.0                      N/A
# 1380                0.0                      N/A
# 1381                0.0                      N/A
#
#                                                 buyLink  year  \
# 0     http://books.google.co.in/books?id=pVP8AQAAQBA...  2013
# 1     http://books.google.co.in/books?id=HFeGvgEACAA...  2010
# 2     https://play.google.com/store/books/details?id...  2007
# 3     https://play.google.com/store/books/details?id...  2013
# 4     http://books.google.co.in/books?id=bIZHCgAAQBA...  2015
# ...                                                 ...   ...
# 1377  http://books.google.co.in/books?id=Fms3AQAAMAA...  1917
# 1378  http://books.google.co.in/books?id=-1gfAQAAMAA...  1921
# 1379  http://books.google.co.in/books?id=WStqa-OykF0...  1910
# 1380  http://books.google.co.in/books?id=E1EEAAAAMBA...  1998
# 1381  https://play.google.com/store/books/details?id...  1881
#
#                          publisher
# 0                        MIT Press
# 1     Manning Publications Company
# 2           "O'Reilly Media, Inc."
# 3           "O'Reilly Media, Inc."
# 4           "O'Reilly Media, Inc."
# ...                            ...
# 1377                 Not available
# 1378                 Not available
# 1379                 Not available
# 1380                 Not available
# 1381                 Not available
#
# [1382 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# book_id                     0
# search_key                  0
# book_title                  0
# book_subtitle               0
# book_authors                0
# book_description            0
# industryIdentifiers         0
# text_readingModes           0
# image_readingModes          0
# pageCount                   0
# categories                  0
# language                    0
# imageLinks                  0
# ratingsCount                0
# averageRating               0
# country                     0
# saleability                 0
# isEbook                     0
# amount_listPrice            0
# currencyCode_listPrice      0
# amount_retailPrice          0
# currencyCode_retailPrice    0
# buyLink                     0
# year                        0
# publisher                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382 entries, 0 to 1381
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   book_id                   1382 non-null   object
#  1   search_key                1382 non-null   object
#  2   book_title                1382 non-null   object
#  3   book_subtitle             1382 non-null   object
#  4   book_authors              1382 non-null   object
#  5   book_description          1382 non-null   object
#  6   industryIdentifiers       1382 non-null   object
#  7   text_readingModes         1382 non-null   bool
#  8   image_readingModes        1382 non-null   bool
#  9   pageCount                 1382 non-null   object
#  10  categories                1382 non-null   object
#  11  language                  1382 non-null   object
#  12  imageLinks                1382 non-null   object
#  13  ratingsCount              1382 non-null   object
#  14  averageRating             1382 non-null   object
#  15  country                   1382 non-null   object
#  16  saleability               1382 non-null   object
#  17  isEbook                   1382 non-null   bool
#  18  amount_listPrice          1382 non-null   object
#  19  currencyCode_listPrice    1382 non-null   object
#  20  amount_retailPrice        1382 non-null   object
#  21  currencyCode_retailPrice  1382 non-null   object
#  22  buyLink                   1382 non-null   object
#  23  year                      1382 non-null   object
#  24  publisher                 1382 non-null   object
# dtypes: bool(3), object(22)
# memory usage: 241.7+ KB

# %%
df['ratingsCount'] = pd.to_numeric(df['ratingsCount'], errors='coerce').fillna(0).astype(int)
df['pageCount'] = pd.to_numeric(df['pageCount'], errors='coerce').fillna(0).astype(int)
df['averageRating'] = pd.to_numeric(df['averageRating'], errors='coerce').fillna(0).astype(float)
df['amount_listPrice'] = pd.to_numeric(df['amount_listPrice'], errors='coerce').fillna(0).astype(float)
df['amount_retailPrice'] = pd.to_numeric(df['amount_retailPrice'], errors='coerce').fillna(0).astype(float)
df['book_id'] = df['book_id'].astype(str)
df['search_key'] = df['search_key'].astype(str)
df['book_title'] = df['book_title'].astype(str)
df['language'] = df['language'].astype(str)
df['saleability'] = df['saleability'].astype(str)
df['currencyCode_listPrice'] = df['currencyCode_listPrice'].astype(str)
df['currencyCode_retailPrice'] = df['currencyCode_retailPrice'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1382 entries, 0 to 1381
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   book_id                   1382 non-null   object
#  1   search_key                1382 non-null   object
#  2   book_title                1382 non-null   object
#  3   book_subtitle             1382 non-null   object
#  4   book_authors              1382 non-null   object
#  5   book_description          1382 non-null   object
#  6   industryIdentifiers       1382 non-null   object
#  7   text_readingModes         1382 non-null   bool
#  8   image_readingModes        1382 non-null   bool
#  9   pageCount                 1382 non-null   int32
#  10  categories                1382 non-null   object
#  11  language                  1382 non-null   object
#  12  imageLinks                1382 non-null   object
#  13  ratingsCount              1382 non-null   int32
#  14  averageRating             1382 non-null   float64
#  15  country                   1382 non-null   object
#  16  saleability               1382 non-null   object
#  17  isEbook                   1382 non-null   bool
#  18  amount_listPrice          1382 non-null   float64
#  19  currencyCode_listPrice    1382 non-null   object
#  20  amount_retailPrice        1382 non-null   float64
#  21  currencyCode_retailPrice  1382 non-null   object
#  22  buyLink                   1382 non-null   object
#  23  year                      1382 non-null   object
#  24  publisher                 1382 non-null   object
# dtypes: bool(3), float64(3), int32(2), object(17)
# memory usage: 230.9+ KB

# %%
df.to_csv('Books_details_1.csv', index=False)

# %%
dup_df = df[df.duplicated()]
dup_df
# Out:
#            book_id search_key  \
# 120   On9dEAAAQBAJ     python
# 121   dNdaEAAAQBAJ     python
# 122   dJ6FEAAAQBAJ     python
# 123   yYKGDwAAQBAJ     python
# 124   VQDgDAAAQBAJ     python
# ...            ...        ...
# 1335  JrYzAQAAMAAJ        sql
# 1336  71BzZGHj-XMC        sql
# 1337  RhRQAAAAYAAJ        sql
# 1338  ieksAAAAYAAJ        sql
# 1339  fEFGAQAAIAAJ        sql
#
#                                              book_title  \
# 120                     Python Concurrency with Asyncio
# 121                            A Journey to Core Python
# 122                   Time Series Forecasting in Python
# 123                          Python Network Programming
# 124                                    Mastering Python
# ...                                                 ...
# 1335    Materialy po i︠a︡feticheskomu i︠a︡zykoznanii︠u︡
# 1336               Königliches Hof- und Nationaltheater
# 1337  Abhandlungen und Berichte des Königl. Zoologis...
# 1338                            Le réveil de la musique
# 1339  Charles Le Brun et les arts sous Louis XIV le ...
#
#                                           book_subtitle  \
# 120                                                 N/A
# 121   Experience the Applications of Tuples, Diction...
# 122                                                 N/A
# 123   Conquer all your networking challenges with th...
# 124                                                 N/A
# ...                                                 ...
# 1335                                                N/A
# 1336                                               1879
# 1337                                                N/A
# 1338  ou, étude rendue d'une facilité extrême et ses...
# 1339  sa vie, son oeuvre, ses écrits, ses contempora...
#
#                                            book_authors  \
# 120                                      Matthew Fowler
# 121   Girish Kumar , Dr. Ajay Shriram Kushwaha, Raji...
# 122                                      Marco Peixeiro
# 123   Abhishek Ratan, Eric Chou, Pradeeban Kathirave...
# 124                                     Rick van Hattem
# ...                                                 ...
# 1335                                                N/A
# 1336                                                N/A
# 1337                                                N/A
# 1338                                      Louis A. Ivon
# 1339                                        Henry Jouin
#
#                                        book_description industryIdentifiers  \
# 120   Learn how to speed up slow Python code with co...      ISBN_13ISBN_10
# 121   Come and join hands together to learn Python f...      ISBN_13ISBN_10
# 122   Build predictive models from time-based patter...      ISBN_13ISBN_10
# 123   Power up your network applications with Python...      ISBN_13ISBN_10
# 124   Master the art of writing beautiful and powerf...      ISBN_13ISBN_10
# ...                                                 ...                 ...
# 1335                          No description available.               OTHER
# 1336                          No description available.               OTHER
# 1337                          No description available.               OTHER
# 1338                          No description available.               OTHER
# 1339                          No description available.               OTHER
#
#       text_reading_modes  image_reading_modes page_count  ... country  \
# 120                False                False        374  ...     N/A
# 121                 True                 True        308  ...     N/A
# 122                 True                False        454  ...     N/A
# 123                 True                 True        763  ...     N/A
# 124                 True                 True        486  ...     N/A
# ...                  ...                  ...        ...  ...     ...
# 1335               False                 True        876  ...     N/A
# 1336               False                 True        784  ...     N/A
# 1337               False                 True        574  ...     N/A
# 1338               False                 True        432  ...     N/A
# 1339               False                 True        416  ...     N/A
#
#        saleability isEbook list_price currencycode_listprice retail_price  \
# 120   NOT_FOR_SALE   False          0                    N/A            0
# 121       FOR_SALE    True      566.4                    INR        283.2
# 122       FOR_SALE    True    2960.62                    INR      2960.62
# 123       FOR_SALE    True    1108.01                    INR          554
# 124       FOR_SALE    True    3163.57                    INR      3163.57
# ...            ...     ...        ...                    ...          ...
# 1335          FREE    True          0                    N/A            0
# 1336          FREE    True          0                    N/A            0
# 1337          FREE    True          0                    N/A            0
# 1338          FREE    True          0                    N/A            0
# 1339          FREE    True          0                    N/A            0
#
#      currencycode_retailprice  \
# 120                       N/A
# 121                       INR
# 122                       INR
# 123                       INR
# 124                       INR
# ...                       ...
# 1335                      N/A
# 1336                      N/A
# 1337                      N/A
# 1338                      N/A
# 1339                      N/A
#
#                                                buy_link  year  \
# 120   http://books.google.co.in/books?id=On9dEAAAQBA...  2022
# 121   https://play.google.com/store/books/details?id...   286
# 122   https://play.google.com/store/books/details?id...  2022
# 123   https://play.google.com/store/books/details?id...  2019
# 124   https://play.google.com/store/books/details?id...  2016
# ...                                                 ...   ...
# 1335  https://play.google.com/store/books/details?id...  1910
# 1336  https://play.google.com/store/books/details?id...  1879
# 1337  https://play.google.com/store/books/details?id...  1903
# 1338  https://play.google.com/store/books/details?id...  1877
# 1339  https://play.google.com/store/books/details?id...  1889
#
#                  publisher
# 120     Simon and Schuster
# 121       BPB Publications
# 122     Simon and Schuster
# 123   Packt Publishing Ltd
# 124   Packt Publishing Ltd
# ...                    ...
# 1335                   N/A
# 1336                   N/A
# 1337                   N/A
# 1338                   N/A
# 1339                   N/A
#
# [150 rows x 25 columns]

# %%
import pymysql
from sqlalchemy import create_engine

# MySQL connection
engine = create_engine('mysql+pymysql://root:mysql@localhost/Book_details')

df.to_sql('Book_details', engine, if_exists='replace', index=False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1460\1378838111.py:7: UserWarning: The provided table name 'Book_details' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql('Book_details', engine, if_exists='replace', index=False)
# 1400

# %%
df['saleability'].unique()
# Out:
# array(['FOR_SALE', 'NOT_FOR_SALE', 'FREE'], dtype=object)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="mysql",
  database="book_details"
)

mycursor = mydb.cursor()

mycursor.execute("""CREATE TABLE IF NOT EXISTS books_details1 (
book_id VARCHAR(255) PRIMARY KEY,
search_key VARCHAR(255),
book_title VARCHAR(255), 
book_subtitle TEXT,
book_authors TEXT,
book_description TEXT,
industryIdentifiers TEXT,
text_readingModes BOOLEAN,
image_readingModes BOOLEAN, 
pageCount INT,
categories TEXT, 
language VARCHAR(50), 
imageLinks TEXT,
ratingsCount INT,
averageRating dec(3,2),
country VARCHAR(50),
saleability VARCHAR(50),
isEbook BOOLEAN, 
amount_listPrice dec(10,2),
currencyCode_listPrice VARCHAR(50),
amount_retailPrice dec(10,2),
currencycode_retailprice VARCHAR(50),
buyLink TEXT,
year TEXT,
publisher TEXT
);""")

# %%
# Import libraries
import pandas as pd
from sqlalchemy import create_engine
import mysql.connector

# MySQL connection details
user = 'root'
password = 'mysql'
host = 'localhost'
database = 'book_details'

# Create SQLAlchemy engine
connection_string = f'mysql+mysqlconnector://{user}:{password}@{host}/{database}'
engine = create_engine(connection_string)

# Sample DataFrame
print(df.head())

# Insert DataFrame into MySQL table
df.to_sql(name='books_details', con=engine, if_exists='replace', index=False)

# Verify the insertion
conn = mysql.connector.connect(user=user, password=password, host=host, database=database)
cursor = conn.cursor()
cursor.execute("SELECT * FROM books_details")
result = cursor.fetchall()
for row in result:
    print(row)

# Close connection
cursor.close()
conn.close()
# Out:
#         book_id search_key                                         book_title  \
# 0  pVP8AQAAQBAJ     python  Introduction to Computation and Programming Us...
# 1  HFeGvgEACAAJ     python                              The Quick Python Book
# 2  nEJ-jcYF2fMC     python                                    Learning Python
# 3  4pgQfXQvekcC     python                                    Learning Python
# 4  bIZHCgAAQBAJ     python                                      Fluent Python
#
#                                book_subtitle                     book_authors  \
# 0                                        N/A      John V. Guttag, John Guttag
# 1                                        N/A  Vernon L. Ceder, Naomi R. Ceder
# 2                                        N/A                        Mark Lutz
# 3       Powerful Object-Oriented Programming                        Mark Lutz
# 4  Clear, Concise, and Effective Programming                  Luciano Ramalho
#
#                                     book_description industryIdentifiers  \
# 0  An introductory text that teaches students the...      ISBN_13ISBN_10
# 1  Introduces the programming language's syntax, ...      ISBN_10ISBN_13
# 2  Portable, powerful, and a breeze to use, Pytho...      ISBN_13ISBN_10
# 3  Get a comprehensive, in-depth introduction to ...      ISBN_13ISBN_10
# 4  Python’s simplicity lets you become productive...      ISBN_13ISBN_10
#
#    text_readingModes  image_readingModes  pageCount  ... country  \
# 0              False                True        315  ...     N/A
# 1              False               False        336  ...     N/A
# 2               True                True        749  ...     N/A
# 3               True                True       1740  ...     N/A
# 4               True                True        755  ...     N/A
#
#     saleability isEbook  amount_listPrice  currencyCode_listPrice  \
# 0  NOT_FOR_SALE   False              0.00                     N/A
# 1  NOT_FOR_SALE   False              0.00                     N/A
# 2      FOR_SALE    True           3235.55                     INR
# 3      FOR_SALE    True           3540.00                     INR
# 4  NOT_FOR_SALE   False              0.00                     N/A
#
#   amount_retailPrice currencyCode_retailPrice  \
# 0               0.00                      N/A
# 1               0.00                      N/A
# 2            3235.55                      INR
# 3            3540.00                      INR
# 4               0.00                      N/A
#
#                                              buyLink  year  \
# 0  http://books.google.co.in/books?id=pVP8AQAAQBA...  2013
# 1  http://books.google.co.in/books?id=HFeGvgEACAA...  2010
# 2  https://play.google.com/store/books/details?id...  2007
# 3  https://play.google.com/store/books/details?id...  2013
# 4  http://books.google.co.in/books?id=bIZHCgAAQBA...  2015
#
#                       publisher
# 0                     MIT Press
# 1  Manning Publications Company
# 2        "O'Reilly Media, Inc."
# 3        "O'Reilly Media, Inc."
# 4        "O'Reilly Media, Inc."
#
# [5 rows x 25 columns]
# ('pVP8AQAAQBAJ', 'python', 'Introduction to Computation and Programming Using Python', 'N/A', 'John V. Guttag, John Guttag', 'An introductory text that teaches students the art of computational problem solving, covering topics that range from simple algorithms to information visualization.', 'ISBN_13ISBN_10', 0, 1, 315, 'Computers', 'en', 'http://books.google.com/books/content?id=pVP8AQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=pVP8AQAAQBAJ&dq=python&hl=&source=gbs_api', '2013', 'MIT Press')
# ('HFeGvgEACAAJ', 'python', 'The Quick Python Book', 'N/A', 'Vernon L. Ceder, Naomi R. Ceder', "Introduces the programming language's syntax, control flow, and basic data structures and covers its interaction with applications and mangement of large collections of code.", 'ISBN_10ISBN_13', 0, 0, 336, 'Computers', 'en', 'http://books.google.com/books/content?id=HFeGvgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=HFeGvgEACAAJ&dq=python&hl=&source=gbs_api', '2010', 'Manning Publications Company')
# ('nEJ-jcYF2fMC', 'python', 'Learning Python', 'N/A', 'Mark Lutz', "Portable, powerful, and a breeze to use, Python is ideal for both standalone programs and scripting applications. With this hands-on book, you can master the fundamentals of the core Python language quickly and efficiently, whether you're new to programming or just new to Python. Once you finish, you will know enough about the language to use it in any application domain you choose. Learning Python is based on material from author Mark Lutz's popular training courses, which he's taught over the past decade. Each chapter is a self-contained lesson that helps you thoroughly understand a key component of Python before you continue. Along with plenty of annotated examples, illustrations, and chapter summaries, every chapter also contains Brain Builder, a unique section with practical exercises and review quizzes that let you practice new skills and test your understanding as you go. This book covers: Types and Operations -- Python's major built-in object types in depth: numbers, lists, dictionaries, and more Statements and Syntax -- the code you type to create and process objects in Python, along with Python's general syntax model Functions -- Python's basic procedural tool for structuring and reusing code Modules -- packages of statements, functions, and other tools organized into larger components Classes and OOP -- Python's optional object-oriented programming tool for structuring code for customization and reuse Exceptions and Tools -- exception handling model and statements, plus a look at development tools for writing larger programs Learning Python gives you a deep and complete understanding of the language that will help you comprehend any application-level examples of Python that you later encounter. If you're ready to discover what Google and YouTube see in Python, this book is the best way to get started.", 'ISBN_13ISBN_10', 1, 1, 749, 'Computers', 'en', 'http://books.google.com/books/content?id=nEJ-jcYF2fMC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 26, 4.0, 'N/A', 'FOR_SALE', 1, 3235.55, 'INR', 3235.55, 'INR', 'https://play.google.com/store/books/details?id=nEJ-jcYF2fMC&source=gbs_api', '2007', '"O\'Reilly Media, Inc."')
# ('4pgQfXQvekcC', 'python', 'Learning Python', 'Powerful Object-Oriented Programming', 'Mark Lutz', 'Get a comprehensive, in-depth introduction to the core Python language with this hands-on book. Based on author Mark Lutz’s popular training course, this updated fifth edition will help you quickly write efficient, high-quality code with Python. It’s an ideal way to begin, whether you’re new to programming or a professional developer versed in other languages. Complete with quizzes, exercises, and helpful illustrations, this easy-to-follow, self-paced tutorial gets you started with both Python 2.7 and 3.3— the latest releases in the 3.X and 2.X lines—plus all other releases in common use today. You’ll also learn some advanced language features that recently have become more common in Python code. Explore Python’s major built-in object types such as numbers, lists, and dictionaries Create and process objects with Python statements, and learn Python’s general syntax model Use functions to avoid code redundancy and package code for reuse Organize statements, functions, and other tools into larger components with modules Dive into classes: Python’s object-oriented programming tool for structuring code Write large programs with Python’s exception-handling model and development tools Learn advanced Python tools, including decorators, descriptors, metaclasses, and Unicode processing', 'ISBN_13ISBN_10', 1, 1, 1740, 'Computers', 'en', 'http://books.google.com/books/content?id=4pgQfXQvekcC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 4, 3.5, 'N/A', 'FOR_SALE', 1, 3540.0, 'INR', 3540.0, 'INR', 'https://play.google.com/store/books/details?id=4pgQfXQvekcC&source=gbs_api', '2013', '"O\'Reilly Media, Inc."')
# ('bIZHCgAAQBAJ', 'python', 'Fluent Python', 'Clear, Concise, and Effective Programming', 'Luciano Ramalho', 'Python’s simplicity lets you become productive quickly, but this often means you aren’t using everything it has to offer. With this hands-on guide, you’ll learn how to write effective, idiomatic Python code by leveraging its best—and possibly most neglected—features. Author Luciano Ramalho takes you through Python’s core language features and libraries, and shows you how to make your code shorter, faster, and more readable at the same time. Many experienced programmers try to bend Python to fit patterns they learned from other languages, and never discover Python features outside of their experience. With this book, those Python programmers will thoroughly learn how to become proficient in Python 3. This book covers: Python data model: understand how special methods are the key to the consistent behavior of objects Data structures: take full advantage of built-in types, and understand the text vs bytes duality in the Unicode age Functions as objects: view Python functions as first-class objects, and understand how this affects popular design patterns Object-oriented idioms: build classes by learning about references, mutability, interfaces, operator overloading, and multiple inheritance Control flow: leverage context managers, generators, coroutines, and concurrency with the concurrent.futures and asyncio packages Metaprogramming: understand how properties, attribute descriptors, class decorators, and metaclasses work', 'ISBN_13ISBN_10', 1, 1, 755, 'Computers', 'en', 'http://books.google.com/books/content?id=bIZHCgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 2, 5.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=bIZHCgAAQBAJ&dq=python&hl=&source=gbs_api', '2015', '"O\'Reilly Media, Inc."')
# ('DjxZEAAAQBAJ', 'python', 'The Python Book', 'N/A', 'Rob Mastrodomenico', 'The Python Book Discover the power of one of the fastest growing programming languages in the world with this insightful new resource The Python Book delivers an essential introductory guide to learning Python for anyone who works with data but does not have experience in programming. The author, an experienced data scientist and Python programmer, shows readers how to use Python for data analysis, exploration, cleaning, and wrangling. Readers will learn what in the Python language is important for data analysis, and why. The Python Book offers readers a thorough and comprehensive introduction to Python that is both simple enough to be ideal for a novice programmer, yet robust to be useful for those more experienced in the language. The book assists budding programmers to gradually increase their skills as they move through the book, always with an understanding of what they are covering and why it is useful. Used by major companies like Google, Facebook, Instagram, Spotify, and more, Python promises to remain central to the programming landscape for years to come. Containing a thorough discussion of Python programming topics like variables, equalities and comparisons, tuple and dictionary data types, while and for loops, and if statements, readers will also learn: How to use highly useful Python programming libraries, including Pandas and Matplotlib How to write Python functions and classes How to write and use Python scripts To deal with different data types within Python Perfect for statisticians, computer scientists, software programmers, and practitioners working in private industry and medicine, The Python Book will also be of interest to students in any of the aforementioned fields. As it assumes no programming experience or knowledge, the book is ideal for those who work with data and want to learn to use Python to enhance their work.', 'ISBN_13ISBN_10', 1, 1, 348, 'Mathematics', 'en', 'http://books.google.com/books/content?id=DjxZEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FOR_SALE', 1, 5766.66, 'INR', 5766.66, 'INR', 'https://play.google.com/store/books/details?id=DjxZEAAAQBAJ&source=gbs_api', '2022', 'John Wiley & Sons')
# ('zjqzDAEACAAJ', 'python', 'Python for Everybody', 'Exploring Data in Python 3', 'Charles R. Severance', 'Python for Everybody is designed to introduce students to programming and software development through the lens of exploring data. You can think of the Python programming language as your tool to solve data problems that are beyond the capability of a spreadsheet.Python is an easy to use and easy to learn programming language that is freely available on Macintosh, Windows, or Linux computers. So once you learn Python you can use it for the rest of your career without needing to purchase any software.This book uses the Python 3 language. The earlier Python 2 version of this book is titled "Python for Informatics: Exploring Information".There are free downloadable electronic copies of this book in various formats and supporting materials for the book at www.pythonlearn.com. The course materials are available to you under a Creative Commons License so you can adapt them to teach your own Python course.', 'ISBN_10ISBN_13', 0, 0, 242, 'N/A', 'en', 'http://books.google.com/books/content?id=zjqzDAEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 1, 5.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=zjqzDAEACAAJ&dq=python&hl=&source=gbs_api', '2016', 'Not available')
# ('6omNDQAAQBAJ', 'python', 'Python Data Science Handbook', 'Essential Tools for Working with Data', 'Jake VanderPlas', 'For many researchers, Python is a first-class tool mainly because of its libraries for storing, manipulating, and gaining insight from data. Several resources exist for individual pieces of this data science stack, but only with the Python Data Science Handbook do you get them all—IPython, NumPy, Pandas, Matplotlib, Scikit-Learn, and other related tools. Working scientists and data crunchers familiar with reading and writing Python code will find this comprehensive desk reference ideal for tackling day-to-day issues: manipulating, transforming, and cleaning data; visualizing different types of data; and using data to build statistical or machine learning models. Quite simply, this is the must-have reference for scientific computing in Python. With this handbook, you’ll learn how to use: IPython and Jupyter: provide computational environments for data scientists using Python NumPy: includes the ndarray for efficient storage and manipulation of dense data arrays in Python Pandas: features the DataFrame for efficient storage and manipulation of labeled/columnar data in Python Matplotlib: includes capabilities for a flexible range of data visualizations in Python Scikit-Learn: for efficient and clean Python implementations of the most important and established machine learning algorithms', 'ISBN_13ISBN_10', 1, 1, 609, 'Computers', 'en', 'http://books.google.com/books/content?id=6omNDQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=6omNDQAAQBAJ&dq=python&hl=&source=gbs_api', '2016', '"O\'Reilly Media, Inc."')
# ('rtJCEAAAQBAJ', 'python', 'Python for Geeks', 'Build production-ready applications using advanced Python concepts and industry best practices', 'Muhammad Asif', "Take your Python skills to the next level to develop scalable, real-world applications for local as well as cloud deployment Key FeaturesAll code examples have been tested with Python 3.7 and Python 3.8 and are expected to work with any future 3.x releaseLearn how to build modular and object-oriented applications in PythonDiscover how to use advanced Python techniques for the cloud and clustersBook Description Python is a multipurpose language that can be used for multiple use cases. Python for Geeks will teach you how to advance in your career with the help of expert tips and tricks. You'll start by exploring the different ways of using Python optimally, both from the design and implementation point of view. Next, you'll understand the life cycle of a large-scale Python project. As you advance, you'll focus on different ways of creating an elegant design by modularizing a Python project and learn best practices and design patterns for using Python. You'll also discover how to scale out Python beyond a single thread and how to implement multiprocessing and multithreading in Python. In addition to this, you'll understand how you can not only use Python to deploy on a single machine but also use clusters in private as well as in public cloud computing environments. You'll then explore data processing techniques, focus on reusable, scalable data pipelines, and learn how to use these advanced techniques for network automation, serverless functions, and machine learning. Finally, you'll focus on strategizing web development design using the techniques and best practices covered in the book. By the end of this Python book, you'll be able to do some serious Python programming for large-scale complex projects. What you will learnUnderstand how to design and manage complex Python projectsStrategize test-driven development (TDD) in PythonExplore multithreading and multiprogramming in PythonUse Python for data processing with Apache Spark and Google Cloud Platform (GCP)Deploy serverless programs on public clouds such as GCPUse Python to build web applications and application programming interfacesApply Python for network automation and serverless functionsGet to grips with Python for data analysis and machine learningWho this book is for This book is for intermediate-level Python developers in any field who are looking to build their skills to develop and manage large-scale complex projects. Developers who want to create reusable modules and Python libraries and cloud developers building applications for cloud deployment will also find this book useful. Prior experience with Python will help you get the most out of this book.", 'ISBN_13ISBN_10', 1, 1, 546, 'Computers', 'en', 'http://books.google.com/books/content?id=rtJCEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FOR_SALE', 1, 3163.57, 'INR', 3163.57, 'INR', 'https://play.google.com/store/books/details?id=rtJCEAAAQBAJ&source=gbs_api', '2021', 'Packt Publishing Ltd')
# ('HjDECQAAQBAJ', 'python', 'Introduction to Programming in Python', 'An Interdisciplinary Approach', 'Robert Sedgewick, Kevin Wayne, Robert Dondero', 'Today, anyone in a scientific or technical discipline needs programming skills. Python is an ideal first programming language, and Introduction to Programming in Python is the best guide to learning it. Princeton University’s Robert Sedgewick, Kevin Wayne, and Robert Dondero have crafted an accessible, interdisciplinary introduction to programming in Python that emphasizes important and engaging applications, not toy problems. The authors supply the tools needed for students to learn that programming is a natural, satisfying, and creative experience. This example-driven guide focuses on Python’s most useful features and brings programming to life for every student in the sciences, engineering, and computer science. Coverage includes Basic elements of programming: variables, assignment statements, built-in data types, conditionals, loops, arrays, and I/O, including graphics and sound Functions, modules, and libraries: organizing programs into components that can be independently debugged, maintained, and reused Object-oriented programming and data abstraction: objects, modularity, encapsulation, and more Algorithms and data structures: sort/search algorithms, stacks, queues, and symbol tables Examples from applied math, physics, chemistry, biology, and computer science—all compatible with Python 2 and 3 Drawing on their extensive classroom experience, the authors provide Q&As, exercises, and opportunities for creative practice throughout. An extensive amount of supplementary information is available at introcs.cs.princeton.edu/python. With source code, I/O libraries, solutions to selected exercises, and much more, this companion website empowers people to use their own computers to teach and learn the material.', 'ISBN_13ISBN_10', 1, 1, 1487, 'Computers', 'en', 'http://books.google.com/books/content?id=HjDECQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FOR_SALE', 1, 3350.82, 'INR', 3350.82, 'INR', 'https://play.google.com/store/books/details?id=HjDECQAAQBAJ&source=gbs_api', '2015', 'Addison-Wesley Professional')
# ('1FL-ygAACAAJ', 'python', 'A Python Book', 'Beginning Python, Advanced Python, and Python Exercises', 'Dave Kuhlman', 'This document is a self learning document for a course in Python programming. This course contains (1) a part for beginners, (2) a discussion of several advanced topics that are of interest to Python programmers, and (3) a Pythonworkbook with lots of exercises.', 'ISBN_10ISBN_13', 0, 0, 202, 'Computers', 'en', 'http://books.google.com/books/content?id=1FL-ygAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=1FL-ygAACAAJ&dq=python&hl=&source=gbs_api', '2011', 'Platypus Global Media')
# ('d_f1DwAAQBAJ', 'python', 'Python Workout', '50 ten-minute exercises', 'Reuven M. Lerner', "The only way to master a skill is to practice. In Python Workout, author Reuven M. Lerner guides you through 50 carefully selected exercises that invite you to flex your programming muscles. As you take on each new challenge, you’ll build programming skill and confidence. Summary The only way to master a skill is to practice. In Python Workout, author Reuven M. Lerner guides you through 50 carefully selected exercises that invite you to flex your programming muscles. As you take on each new challenge, you’ll build programming skill and confidence. The thorough explanations help you lock in what you’ve learned and apply it to your own projects. Along the way, Python Workout provides over four hours of video instruction walking you through the solutions to each exercise and dozens of additional exercises for you to try on your own. Purchase of the print book includes a free eBook in PDF, Kindle, and ePub formats from Manning Publications. About the technology To become a champion Python programmer you need to work out, building mental muscle with your hands on the keyboard. Each carefully selected exercise in this unique book adds to your Python prowess—one important skill at a time. About the book Python Workout presents 50 exercises that focus on key Python 3 features. In it, expert Python coach Reuven Lerner guides you through a series of small projects, practicing the skills you need to tackle everyday tasks. You’ll appreciate the clear explanations of each technique, and you can watch Reuven solve each exercise in the accompanying videos. What's inside 50 hands-on exercises and solutions Coverage of all Python data types Dozens more bonus exercises for extra practice About the reader For readers with basic Python knowledge. About the author Reuven M. Lerner teaches Python and data science to companies around the world. Table of Contents 1 Numeric types 2 Strings 3 Lists and tuples 4 Dictionaries and sets 5 Files 6 Functions 7 Functional programming with comprehensions 8 Modules and packages 9 Objects 10 Iterators and generators", 'ISBN_13ISBN_10', 0, 0, 246, 'Computers', 'en', 'http://books.google.com/books/content?id=d_f1DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=d_f1DwAAQBAJ&dq=python&hl=&source=gbs_api', '2020', 'Manning')
# ('ZPneDQAAQBAJ', 'python', 'Invent Your Own Computer Games with Python, 4th Edition', 'N/A', 'Al Sweigart', 'Invent Your Own Computer Games with Python will teach you how to make computer games using the popular Python programming language—even if you’ve never programmed before! Begin by building classic games like Hangman, Guess the Number, and Tic-Tac-Toe, and then work your way up to more advanced games, like a text-based treasure hunting game and an animated collision-dodging game with sound effects. Along the way, you’ll learn key programming and math concepts that will help you take your game programming to the next level. Learn how to: –Combine loops, variables, and flow control statements into real working programs –Choose the right data structures for the job, such as lists, dictionaries, and tuples –Add graphics and animation to your games with the pygame module –Handle keyboard and mouse input –Program simple artificial intelligence so you can play against the computer –Use cryptography to convert text messages into secret code –Debug your programs and find common errors As you work through each game, you’ll build a solid foundation in Python and an understanding of computer science fundamentals. What new game will you create with the power of Python? The projects in this book are compatible with Python 3.', 'ISBN_13ISBN_10', 1, 1, 377, 'Computers', 'en', 'http://books.google.com/books/content?id=ZPneDQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 1, 5.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=ZPneDQAAQBAJ&dq=python&hl=&source=gbs_api', '2016', 'No Starch Press')
# ('KTgzEAAAQBAJ', 'python', 'Classic Computer Science Problems in Swift', 'Essential techniques for practicing programmers', 'David Kopec', 'Summary Classic Computer Science Problems in Swift invites readers to invest their energy in some foundational techniques that have been proven to stand the test of time. Along the way they\'ll learn intermediate and advanced features of the Swift programming language, a worthwhile skill in its own right. Purchase of the print book includes a free eBook in PDF, Kindle, and ePub formats from Manning Publications. About the Technology Don\'t just learn another language. Become a better programmer instead. Today\'s awesome iOS apps stand on the shoulders of classic algorithms, coding techniques, and engineering principles. Master these core skills in Swift, and you\'ll be ready for AI, data-centric programming, machine learning, and the other development challenges that will define the next decade. About the Book Classic Computer Science Problems in Swift deepens your Swift language skills by exploring foundational coding techniques and algorithms. As you work through examples in search, clustering, graphs, and more, you\'ll remember important things you\'ve forgotten and discover classic solutions to your "new" problems. You\'ll appreciate author David Kopec\'s amazing ability to connect the core disciplines of computer science to the real-world concerns of apps, data, performance, and even nailing your next job interview! What\'s Inside Breadth-first, depth-first, and A* search algorithms Constraint-satisfaction problems Solving problems with graph algorithms Neural networks, genetic algorithms, and more All examples written in Swift 4.1 About the Reader For readers comfortable with the basics of Swift. About the Author David Kopec is an assistant professor of computer science and innovation at Champlain College in Burlington, Vermont. He is an experienced iOS developer and the author of Dart for Absolute Beginners. Table of Contents Small problems Search problems Constraint-satisfaction problems Graph problems Genetic algorithms K-means clustering Fairly simple neural networks Miscellaneous problems', 'ISBN_13ISBN_10', 1, 0, 322, 'Computers', 'en', 'http://books.google.com/books/content?id=KTgzEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FOR_SALE', 1, 2086.24, 'INR', 2086.24, 'INR', 'https://play.google.com/store/books/details?id=KTgzEAAAQBAJ&source=gbs_api', '2018', 'Simon and Schuster')
# ('BcN0swEACAAJ', 'python', 'Python Tricks', 'The Book', 'Dan Bader', '"I don\'t even feel like I\'ve scratched the surface of what I can do with Python" With Python Tricks: The Book you\'ll discover Python\'s best practices and the power of beautiful & Pythonic code with simple examples and a step-by-step narrative. You\'ll get one step closer to mastering Python, so you can write beautiful and idiomatic code that comes to you naturally. Learning the ins and outs of Python is difficult-and with this book you\'ll be able to focus on the practical skills that really matter. Discover the "hidden gold" in Python\'s standard library and start writing clean and Pythonic code today. Who Should Read This Book: If you\'re wondering which lesser known parts in Python you should know about, you\'ll get a roadmap with this book. Discover cool (yet practical!) Python tricks and blow your coworkers\' minds in your next code review. If you\'ve got experience with legacy versions of Python, the book will get you up to speed with modern patterns and features introduced in Python 3 and backported to Python 2. If you\'ve worked with other programming languages and you want to get up to speed with Python, you\'ll pick up the idioms and practical tips you need to become a confident and effective Pythonista. If you want to make Python your own and learn how to write clean and Pythonic code, you\'ll discover best practices and little-known tricks to round out your knowledge. What Python Developers Say About The Book: "I kept thinking that I wished I had access to a book like this when I started learning Python many years ago." - Mariatta Wijaya, Python Core Developer "This book makes you write better Python code!" - Bob Belderbos, Software Developer at Oracle "Far from being just a shallow collection of snippets, this book will leave the attentive reader with a deeper understanding of the inner workings of Python as well as an appreciation for its beauty." - Ben Felder, Pythonista "It\'s like having a seasoned tutor explaining, well, tricks!" - Daniel Meyer, Sr. Desktop Administrator at Tesla Inc.', 'ISBN_10ISBN_13', 0, 0, 302, 'Computers', 'en', 'http://books.google.com/books/content?id=BcN0swEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 1, 4.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=BcN0swEACAAJ&dq=python&hl=&source=gbs_api', '2017', 'Dan Bader')
# ('QmNAuwEACAAJ', 'python', 'Clean Code in Python', 'Refactor Your Legacy Code Base', 'Mariano Anaya', 'Getting the most out of Python to improve your codebase Key Features Save maintenance costs by learning to fix your legacy codebase Learn the principles and techniques of refactoring Apply microservices to your legacy systems by implementing practical techniques Book Description Python is currently used in many different areas such as software construction, systems administration, and data processing. In all of these areas, experienced professionals can find examples of inefficiency, problems, and other perils, as a result of bad code. After reading this book, readers will understand these problems, and more importantly, how to correct them. The book begins by describing the basic elements of writing clean code and how it plays an important role in Python programming. You will learn about writing efficient and readable code using the Python standard library and best practices for software design. You will learn to implement the SOLID principles in Python and use decorators to improve your code. The book delves more deeply into object oriented programming in Python and shows you how to use objects with descriptors and generators. It will also show you the design principles of software testing and how to resolve software problems by implementing design patterns in your code. In the final chapter we break down a monolithic application to a microservice one, starting from the code as the basis for a solid platform. By the end of the book, you will be proficient in applying industry approved coding practices to design clean, sustainable and readable Python code. What you will learn Set up tools to effectively work in a development environment Explore how the magic methods of Python can help us write better code Examine the traits of Python to create advanced object-oriented design Understand removal of duplicated code using decorators and descriptors Effectively refactor code with the help of unit tests Learn to implement the SOLID principles in Python Who this book is for This book will appeal to team leads, software architects and senior software engineers who would like to work on their legacy systems to save cost and improve efficiency. A strong understanding of Programming is assumed.', 'ISBN_10ISBN_13', 0, 0, 332, 'Computers', 'en', 'http://books.google.com/books/content?id=QmNAuwEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=QmNAuwEACAAJ&dq=python&hl=&source=gbs_api', '2018', 'Packt Publishing')
# ('89W8DwAAQBAJ', 'python', 'Introducing Python', 'Modern Computing in Simple Packages', 'Bill Lubanovic', 'Easy to understand and fun to read, this updated edition of Introducing Python is ideal for beginning programmers as well as those new to the language. Author Bill Lubanovic takes you from the basics to more involved and varied topics, mixing tutorials with cookbook-style code recipes to explain concepts in Python 3. End-of-chapter exercises help you practice what you’ve learned. You’ll gain a strong foundation in the language, including best practices for testing, debugging, code reuse, and other development tips. This book also shows you how to use Python for applications in business, science, and the arts, using various Python tools and open source packages.', 'ISBN_13ISBN_10', 1, 1, 634, 'Computers', 'en', 'http://books.google.com/books/content?id=89W8DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FOR_SALE', 1, 2513.4, 'INR', 2513.4, 'INR', 'https://play.google.com/store/books/details?id=89W8DwAAQBAJ&source=gbs_api', '2019', '"O\'Reilly Media, Inc."')
# ('S_SJ2LaZH8EC', 'python', 'Python Cookbook', 'Recipes for Mastering Python 3', 'David Beazley, Brian K. Jones', 'If you need help writing programs in Python 3, or want to update older Python 2 code, this book is just the ticket. Packed with practical recipes written and tested with Python 3.3, this unique cookbook is for experienced Python programmers who want to focus on modern tools and idioms. Inside, youâ??ll find complete recipes for more than a dozen topics, covering the core Python language as well as tasks common to a wide variety of application domains. Each recipe contains code samples you can use in your projects right away, along with a discussion about how and why the solution works. Topics include: Data Structures and Algorithms Strings and Text Numbers, Dates, and Times Iterators and Generators Files and I/O Data Encoding and Processing Functions Classes and Objects Metaprogramming Modules and Packages Network and Web Programming Concurrency Utility Scripting and System Administration Testing, Debugging, and Exceptions C Extensions', 'ISBN_13ISBN_10', 1, 1, 1132, 'Computers', 'en', 'http://books.google.com/books/content?id=S_SJ2LaZH8EC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FOR_SALE', 1, 2950.0, 'INR', 2950.0, 'INR', 'https://play.google.com/store/books/details?id=S_SJ2LaZH8EC&source=gbs_api', '2013', '"O\'Reilly Media, Inc."')
# ('7MmeyhTnqRkC', 'python', 'Dive Into Python', 'N/A', 'Mark Pilgrim', '* Quick start to learning python—very example oriented approach * Book has its own Web site established by the author: http://diveintopython.org/ Author is well known in the Open Source community and the book has a unique quick approach to learning an object oriented language.', 'ISBN_13ISBN_10', 0, 1, 419, 'Computers', 'en', 'http://books.google.com/books/content?id=7MmeyhTnqRkC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=7MmeyhTnqRkC&dq=python&hl=&source=gbs_api', '2004', 'Apress')
# ('6HgFEAAAQBAJ', 'python', 'Taming PYTHON By Programming', 'N/A', 'Jeeva Jose', 'This is a great book for Python Beginner and Advanced Learner which covers Basics to Advanced Python Programming where each topic is explained with the help of Illustrations and Examples. More than 450 solved programs of this book are tested in Python 3.4.3 for windows. The range of Python Topics covered makes this book unique which can be used as a self study material or for instructor assisted teaching. This books covers Python Syllabus of all major national and international universities. Also it includes frequently asked questions for interviews and examination which are provided at the end of each chapter.', 'ISBN_13ISBN_10', 0, 1, 346, 'Computers', 'en', 'http://books.google.com/books/content?id=6HgFEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FOR_SALE', 1, 395.3, 'INR', 276.71, 'INR', 'https://play.google.com/store/books/details?id=6HgFEAAAQBAJ&source=gbs_api', '0000', 'KHANNA PUBLISHING HOUSE')
# ('w1v6DwAAQBAJ', 'python', 'Python Crash Course, 2nd Edition', 'A Hands-On, Project-Based Introduction to Programming', 'Eric Matthes', "The best-selling Python book in the world, with over 1 million copies sold! A fast-paced, no-nonsense, updated guide to programming in Python. If you've been thinking about learning how to code or picking up Python, this internationally bestselling guide to the most popular programming language is your quickest, easiest way to get started and go! Even if you have no experience whatsoever, Python Crash Course, 2nd Edition, will have you writing programs, solving problems, building computer games, and creating data visualizations in no time. You’ll begin with basic concepts like variables, lists, classes, and loops—with the help of fun skill-strengthening exercises for every topic—then move on to making interactive programs and best practices for testing your code. Later chapters put your new knowledge into play with three cool projects: a 2D Space Invaders-style arcade game, a set of responsive data visualizations you’ll build with Python's handy libraries (Pygame, Matplotlib, Plotly, Django), and a customized web app you can deploy online. Why wait any longer? Start your engine and code!", 'ISBN_13ISBN_10', 0, 0, 546, 'Computers', 'en', 'http://books.google.com/books/content?id=w1v6DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 1, 5.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=w1v6DwAAQBAJ&dq=python&hl=&source=gbs_api', '2019', 'No Starch Press')
# ('vnohEAAAQBAJ', 'python', 'Python for Excel', 'N/A', 'Felix Zumstein', "While Excel remains ubiquitous in the business world, recent Microsoft feedback forums are full of requests to include Python as an Excel scripting language. In fact, it's the top feature requested. What makes this combination so compelling? In this hands-on guide, Felix Zumstein--creator of xlwings, a popular open source package for automating Excel with Python--shows experienced Excel users how to integrate these two worlds efficiently. Excel has added quite a few new capabilities over the past couple of years, but its automation language, VBA, stopped evolving a long time ago. Many Excel power users have already adopted Python for daily automation tasks. This guide gets you started. Use Python without extensive programming knowledge Get started with modern tools, including Jupyter notebooks and Visual Studio code Use pandas to acquire, clean, and analyze data and replace typical Excel calculations Automate tedious tasks like consolidation of Excel workbooks and production of Excel reports Use xlwings to build interactive Excel tools that use Python as a calculation engine Connect Excel to databases and CSV files and fetch data from the internet using Python code Use Python as a single tool to replace VBA, Power Query, and Power Pivot", 'ISBN_13ISBN_10', 1, 1, 366, 'Computers', 'en', 'http://books.google.com/books/content?id=vnohEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FOR_SALE', 1, 3764.2, 'INR', 3764.2, 'INR', 'https://play.google.com/store/books/details?id=vnohEAAAQBAJ&source=gbs_api', '2021', '"O\'Reilly Media, Inc."')
# ('mZwbCwAAQBAJ', 'python', 'Think Python', 'N/A', 'Allen B. Downey', 'If you want to learn how to program, working with Python is an excellent way to start. This hands-on guide takes you through the language a step at a time, beginning with basic programming concepts before moving on to functions, recursion, data structures, and object-oriented design. This second edition and its supporting code have been updated for Python 3. Through exercises in each chapter, youâ??ll try out programming concepts as you learn them. Think Python is ideal for students at the high school or college level, as well as self-learners, home-schooled students, and professionals who need to learn programming basics. Beginners just getting their feet wet will learn how to start with Python in a browser. Start with the basics, including language syntax and semantics Get a clear definition of each programming concept Learn about values, variables, statements, functions, and data structures in a logical progression Discover how to work with files and databases Understand objects, methods, and object-oriented programming Use debugging techniques to fix syntax, runtime, and semantic errors Explore interface design, data structures, and GUI-based programs through case studies', 'ISBN_13ISBN_10', 1, 1, 309, 'Computers', 'en', 'http://books.google.com/books/content?id=mZwbCwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=mZwbCwAAQBAJ&dq=python&hl=&source=gbs_api', '2015', '"O\'Reilly Media, Inc."')
# ('93YpDwAAQBAJ', 'python', 'Learn Python 3 the Hard Way', 'A Very Simple Introduction to the Terrifyingly Beautiful World of Computers and Code', 'Zed A. Shaw', 'You Will Learn Python 3! Zed Shaw has perfected the world’s best system for learning Python 3. Follow it and you will succeed—just like the millions of beginners Zed has taught to date! You bring the discipline, commitment, and persistence; the author supplies everything else. In Learn Python 3 the Hard Way, you’ll learn Python by working through 52 brilliantly crafted exercises. Read them. Type their code precisely. (No copying and pasting!) Fix your mistakes. Watch the programs run. As you do, you’ll learn how a computer works; what good programs look like; and how to read, write, and think about code. Zed then teaches you even more in 5+ hours of video where he shows you how to break, fix, and debug your code—live, as he’s doing the exercises. Install a complete Python environment Organize and write code Fix and break code Basic mathematics Variables Strings and text Interact with users Work with files Looping and logic Data structures using lists and dictionaries Program design Object-oriented programming Inheritance and composition Modules, classes, and objects Python packaging Automated testing Basic game development Basic web development It’ll be hard at first. But soon, you’ll just get it—and that will feel great! This course will reward you for every minute you put into it. Soon, you’ll know one of the world’s most powerful, popular programming languages. You’ll be a Python programmer. This Book Is Perfect For Total beginners with zero programming experience Junior developers who know one or two languages Returning professionals who haven’t written code in years Seasoned professionals looking for a fast, simple, crash course in Python 3', 'ISBN_13ISBN_10', 1, 1, 752, 'Computers', 'en', 'http://books.google.com/books/content?id=93YpDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 2, 5.0, 'N/A', 'FOR_SALE', 1, 2617.63, 'INR', 2617.63, 'INR', 'https://play.google.com/store/books/details?id=93YpDwAAQBAJ&source=gbs_api', '2017', 'Addison-Wesley Professional')
# ('f4g9zgEACAAJ', 'python', "Murach's Python Programming (2nd Edition)", 'N/A', 'Joel Murach, Michael Urban', 'If you want to learn how to program but dont know where to start, this is the right book and the right language for you. From the first page, our self-paced approach will help you build competence and confidence in your programming skills. And Python is the best language ever for learning how to program because of its simplicity and breadthtwo features that are hard to find in a single language. But this isnt just a book for beginners! Our self-paced approach also works for experienced programmers, helping you learn Python faster and better than youve ever learned a language before. By the time youre through, you will have mastered the key Python skills that are needed on the job, including those for object-oriented, database, and GUI programming. To make all of this possible, section 1 presents an 8-chapter course that will get anyone off to a great start with Python. Section 2 builds on that base by presenting the other essential skills that every Python programmer should have. Section 3 shows you how to develop object-oriented programs, a critical skillset in todays world. And section 4 shows you how to apply all of the skills that youve already learned as you build database and GUI programs for the real world.', 'ISBN_10ISBN_13', 0, 0, 564, 'N/A', 'en', 'http://books.google.com/books/content?id=f4g9zgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=f4g9zgEACAAJ&dq=python&hl=&source=gbs_api', '2021', 'Not available')
# ('LfbjAQAACAAJ', 'python', 'The Python Book', 'The Ultimate Guide to Coding with Python', 'N/A', 'No description available.', 'ISBN_10ISBN_13', 0, 0, 178, 'N/A', 'en', 'No thumbnail available.', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=LfbjAQAACAAJ&dq=python&hl=&source=gbs_api', '2016', 'Not available')
# ('ZeDmDQAAQBAJ', 'python', 'Programming with Python', 'N/A', 'T R Padmanabhan', 'Based on the latest version of the language, this book offers a self-contained, concise and coherent introduction to programming with Python. The book’s primary focus is on realistic case study applications of Python. Each practical example is accompanied by a brief explanation of the problem-terminology and concepts, followed by necessary program development in Python using its constructs, and simulated testing. Given the open and participatory nature of development, Python has a variety of incorporated data structures, which has made it difficult to present it in a coherent manner. Further, some advanced concepts (super, yield, generator, decorator, etc.) are not easy to explain. The book specially addresses these challenges; starting with a minimal subset of the core, it offers users a step-by-step guide to achieving proficiency.', 'ISBN_13ISBN_10', 1, 1, 349, 'Computers', 'en', 'http://books.google.com/books/content?id=ZeDmDQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FOR_SALE', 1, 9239.4, 'INR', 9239.4, 'INR', 'https://play.google.com/store/books/details?id=ZeDmDQAAQBAJ&source=gbs_api', '2017', 'Springer')
# ...
# ('4G9AAQAAMAAJ', 'sql', 'Zapiski', 'N/A', 'Russkoe arkheologicheskoe obshchestvo, Leningrad. Vostochnoe otdi͡elenie', 'No description available.', 'OTHER', 0, 0, 488, 'Archaeology', 'ru', 'http://books.google.com/books/content?id=4G9AAQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=4G9AAQAAMAAJ&dq=sql&hl=&source=gbs_api', '1921', 'Not available')
# ('aiPtAAAAMAAJ', 'sql', "Notes d'ethnographie et de linguistique nord-africaines", 'N/A', 'S. Biarnay', 'No description available.', 'OTHER', 0, 0, 292, 'African languages', 'fr', 'http://books.google.com/books/content?id=aiPtAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=aiPtAAAAMAAJ&dq=sql&hl=&source=gbs_api', '1924', 'Not available')
# ('9BngAAAAMAAJ', 'sql', 'Zapiski Vostochnago otdi︠e︡lenīi︠a︡ Russkago arkheologicheskago obshchestva', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 0, 490, 'Archaeology', 'ru', 'http://books.google.com/books/content?id=9BngAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=9BngAAAAMAAJ&dq=sql&hl=&source=gbs_api', '1921', 'Not available')
# ('0h5kAAAAMAAJ', 'sql', 'Яфетический сборник', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 0, 444, 'Caucasian languages', 'ru', 'http://books.google.com/books/content?id=0h5kAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=0h5kAAAAMAAJ&dq=sql&hl=&source=gbs_api', '1927', 'Not available')
# ('KdsLAAAAYAAJ', 'sql', 'Die menschlichen Skeletreste aus der Steinzeit des Wauwilersees (Luzern) und ihre Stellung zu anderen anthropologischen Funden aus der Steinzeit', 'N/A', 'Otto Schlaginhaufen', 'No description available.', 'OTHER', 0, 0, 342, 'Anthropology', 'de', 'http://books.google.com/books/content?id=KdsLAAAAYAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=KdsLAAAAYAAJ&dq=sql&hl=&source=gbs_api', '1925', 'Not available')
# ('gpMzAQAAMAAJ', 'sql', 'Die Edda mit historisch-kritischem commentar', 'N/A', 'Richard Constant Boer', 'No description available.', 'OTHER', 0, 0, 832, 'N/A', 'de', 'http://books.google.com/books/content?id=gpMzAQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=gpMzAQAAMAAJ&dq=sql&hl=&source=gbs_api', '1922', 'Not available')
# ('TiMTAQAAMAAJ', 'sql', 'Laerebok i Lappisk: Grammatikk', 'N/A', 'Konrad Nielsen', 'No description available.', 'OTHER', 0, 0, 474, 'Encyclopedias and dictionaries', 'no', 'http://books.google.com/books/content?id=TiMTAQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=TiMTAQAAMAAJ&dq=sql&hl=&source=gbs_api', '1926', 'Not available')
# ('ZLTTAAAAMAAJ', 'sql', 'Ostergötlands runinskrifter', 'granskade och tolkade', 'Erik Brate', 'No description available.', 'OTHER', 0, 0, 382, 'Inscriptions, Runic', 'sv', 'http://books.google.com/books/content?id=ZLTTAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=ZLTTAAAAMAAJ&dq=sql&hl=&source=gbs_api', '1911', 'Not available')
# ('U2glkK7ZfwQC', 'sql', 'Norske gaardnavne: bd. Nordre Bergenhus amt. 1919', 'N/A', 'Oluf Rygh', 'No description available.', 'OTHER', 0, 0, 620, 'Names, Geographical', 'da', 'http://books.google.com/books/content?id=U2glkK7ZfwQC&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=U2glkK7ZfwQC&dq=sql&hl=&source=gbs_api', '1919', 'Not available')
# ('QnEeAQAAMAAJ', 'sql', 'Supplementa entomologica', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 0, 662, 'Entomology', 'de', 'http://books.google.com/books/content?id=QnEeAQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=QnEeAQAAMAAJ&dq=sql&hl=&source=gbs_api', '1926', 'Not available')
# ('NDCaebS78G0C', 'sql', 'Supplementa entomologica: Russland-heft uber Angewandte Entomologie', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 0, 986, 'Entomology', 'de', 'http://books.google.com/books/content?id=NDCaebS78G0C&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=NDCaebS78G0C&dq=sql&hl=&source=gbs_api', '1923', 'Not available')
# ('DAggAQAAMAAJ', 'sql', 'Zeitschrift für mathematischen und naturwissenschaftlichen unterricht', 'Organ für inhalt, methode und organisation des unterrichtes in den exakten wissenschaften an allen schulgattungen ...', 'Volkmar Hoffmann (i.e. Immanuel Carl Volkmar), Heinrich Schotten', 'No description available.', 'OTHER', 0, 0, 632, 'Mathematics', 'de', 'http://books.google.com/books/content?id=DAggAQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=DAggAQAAMAAJ&dq=sql&hl=&source=gbs_api', '1926', 'Not available')
# ('oUCYMxSpyPMC', 'sql', 'Gazzetta ufficiale della Repubblica italiana. Parte prima, 4. serie speciale, Concorsi ed esami', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 0, 1248, 'N/A', 'it', 'http://books.google.com/books/content?id=oUCYMxSpyPMC&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=oUCYMxSpyPMC&dq=sql&hl=&source=gbs_api', '2001', 'Not available')
# ('rm83AAAAMAAJ', 'sql', '"Motor Trips", Eastern America', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 0, 248, 'Automobile travel', 'en', 'http://books.google.com/books/content?id=rm83AAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=rm83AAAAMAAJ&dq=sql&hl=&source=gbs_api', '1924', 'Not available')
# ('dKFMAAAAYAAJ', 'sql', 'Railway Age Gazette', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 0, 1866, 'Railroads', 'en', 'http://books.google.com/books/content?id=dKFMAAAAYAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=dKFMAAAAYAAJ&dq=sql&hl=&source=gbs_api', '1910', 'Not available')
# ('8JQxAQAAMAAJ', 'sql', 'Trade', 'A Journal for Retail Merchants', 'N/A', 'No description available.', 'OTHER', 0, 0, 1516, 'N/A', 'en', 'http://books.google.com/books/content?id=8JQxAQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=8JQxAQAAMAAJ&dq=sql&hl=&source=gbs_api', '1909', 'Not available')
# ('ANhAzwEACAAJ', 'sql', 'House of Sky and Breath', 'N/A', 'Sarah J. Maas', 'No description available.', 'ISBN_10ISBN_13', 0, 0, 805, 'N/A', 'en', 'No thumbnail available.', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=ANhAzwEACAAJ&dq=sql&hl=&source=gbs_api', '2022', 'Not available')
# ('laf5T0K1TeYC', 'sql', "Franck's Etymologisch woordenboek der Nederlandsche taal", 'N/A', 'Johannes Franck, Nicolaas van Wijk', 'No description available.', 'OTHER', 0, 1, 1028, 'Dutch language', 'nl', 'http://books.google.com/books/content?id=laf5T0K1TeYC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FREE', 1, 0.0, 'N/A', 0.0, 'N/A', 'https://play.google.com/store/books/details?id=laf5T0K1TeYC&source=gbs_api', '1912', "s'Gravenhage : M. Nijhoff")
# ('gtxZAAAAcAAJ', 'sql', 'Zeitschrift für die gesammten Naturwissenschaften', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 1, 586, 'N/A', 'de', 'http://books.google.com/books/content?id=gtxZAAAAcAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FREE', 1, 0.0, 'N/A', 0.0, 'N/A', 'https://play.google.com/store/books/details?id=gtxZAAAAcAAJ&source=gbs_api', '1872', 'Not available')
# ('uFgWAAAAYAAJ', 'sql', 'Anleitung beim Studium des baues der Nervösen centralorgane im Gesunden und Kranken sustande', 'N/A', 'Heinrich Obersteiner', 'No description available.', 'OTHER', 0, 1, 544, 'Nervous system', 'de', 'http://books.google.com/books/content?id=uFgWAAAAYAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FREE', 1, 0.0, 'N/A', 0.0, 'N/A', 'https://play.google.com/store/books/details?id=uFgWAAAAYAAJ&source=gbs_api', '1892', 'Not available')
# ('51smEKyjNZMC', 'sql', 'Математический сборник', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 1, 672, 'N/A', 'ru', 'http://books.google.com/books/content?id=51smEKyjNZMC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FREE', 1, 0.0, 'N/A', 0.0, 'N/A', 'https://play.google.com/store/books/details?id=51smEKyjNZMC&source=gbs_api', '1875', 'Not available')
# ('4CajHvft_DgC', 'sql', 'Inscriptiones Galliae Cisalpinae Latinae', 'N/A', 'Theodor Mommsen', 'No description available.', 'OTHER', 0, 1, 616, 'Inscriptions, Latin', 'la', 'http://books.google.com/books/content?id=4CajHvft_DgC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FREE', 1, 0.0, 'N/A', 0.0, 'N/A', 'https://play.google.com/store/books/details?id=4CajHvft_DgC&source=gbs_api', '1872', 'Not available')
# ('EyxRAAAAYAAJ', 'sql', 'Atti parlamentari', 'N/A', 'Italy. Parlamento', 'Consists of separately numbered series of publications of the Parlamento as a whole, the Senato, and the Camera dei deputati. Each session is divided into Disegni di leggi; Documenti; and: Discussioni.', 'OTHER', 0, 0, 2394, 'Italy', 'it', 'http://books.google.com/books/content?id=EyxRAAAAYAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=EyxRAAAAYAAJ&dq=sql&hl=&source=gbs_api', '1913', 'Not available')
# ('9DdRAQAAIAAJ', 'sql', '週刊朝日', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 0, 730, 'Japanese periodicals', 'ja', 'http://books.google.com/books/content?id=9DdRAQAAIAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=9DdRAQAAIAAJ&dq=sql&hl=&source=gbs_api', '2006', 'Not available')
# ('Fms3AQAAMAAJ', 'sql', 'De Ingenieur', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 0, 1018, 'Engineering', 'nl', 'http://books.google.com/books/content?id=Fms3AQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=Fms3AQAAMAAJ&dq=sql&hl=&source=gbs_api', '1917', 'Not available')
# ('-1gfAQAAMAAJ', 'sql', 'Marine Engineering', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 0, 1146, 'Marine engineering', 'en', 'http://books.google.com/books/content?id=-1gfAQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=-1gfAQAAMAAJ&dq=sql&hl=&source=gbs_api', '1921', 'Not available')
# ('WStqa-OykF0C', 'sql', 'Muret-Sanders Enzyklopädisches englisch-deutsches und deutsch-englisches Wörterbuch: Englisch-deutsch, von B. Klatt', 'N/A', 'Eduard Muret', 'No description available.', 'OTHER', 0, 0, 1172, 'English language', 'de', 'http://books.google.com/books/content?id=WStqa-OykF0C&printsec=frontcover&img=1&zoom=1&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=WStqa-OykF0C&dq=sql&hl=&source=gbs_api', '1910', 'Not available')
# ('E1EEAAAAMBAJ', 'sql', 'InfoWorld', 'N/A', 'N/A', 'InfoWorld is targeted to Senior IT professionals. Content is segmented into Channels and Topic Centers. InfoWorld also celebrates people, companies, and projects.', '', 0, 1, 156, 'N/A', 'fr', 'http://books.google.com/books/content?id=E1EEAAAAMBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'NOT_FOR_SALE', 0, 0.0, 'N/A', 0.0, 'N/A', 'http://books.google.co.in/books?id=E1EEAAAAMBAJ&dq=sql&hl=&source=gbs_api', '1998', 'Not available')
# ('1RRBAQAAMAAJ', 'sql', 'JMPA', 'N/A', 'N/A', 'No description available.', 'OTHER', 0, 1, 872, 'Mathematics', 'fr', 'http://books.google.com/books/content?id=1RRBAQAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 0, 0.0, 'N/A', 'FREE', 1, 0.0, 'N/A', 0.0, 'N/A', 'https://play.google.com/store/books/details?id=1RRBAQAAMAAJ&source=gbs_api', '1881', 'Not available')
